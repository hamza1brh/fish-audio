# %% [markdown]
# # OpenAudio S1 Mini Finetuning
#
# Finetune S1 Mini on custom voice data using LoRA.
#
# **Requirements:**
# - Linux with CUDA (Triton required for fast training)
# - 16GB+ VRAM recommended
# - Dataset in LJSpeech format (metadata.csv + wavs/)
#
# **Steps:**
# 1. Environment setup
# 2. Dataset preparation
# 3. VQ token extraction
# 4. Protobuf dataset build
# 5. LoRA finetuning
# 6. Merge and export

# %%
# Cell 1: Environment Setup
import os
import sys
import platform
from pathlib import Path
import subprocess
import shutil
import time

# Navigate to fish-speech root
notebook_dir = Path.cwd()
if notebook_dir.name == 'notebooks':
    project_root = notebook_dir.parent.parent
else:
    project_root = notebook_dir.parent

os.chdir(project_root)
sys.path.insert(0, str(project_root))

print(f"Project root: {project_root}")

import torch

print("\n" + "="*60)
print("ENVIRONMENT CHECK")
print("="*60)
print(f"Python: {sys.version.split()[0]}")
print(f"PyTorch: {torch.__version__}")
print(f"CUDA Available: {torch.cuda.is_available()}")

if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    vram_gb = torch.cuda.get_device_properties(0).total_memory / 1024**3
    print(f"VRAM: {vram_gb:.1f} GB")
    if vram_gb >= 16:
        print("[OK] Sufficient VRAM")
    else:
        print("[WARN] Low VRAM - reduce batch size")
else:
    print("[ERROR] No GPU detected!")

try:
    import triton
    print(f"Triton: {triton.__version__}")
except ImportError:
    print("[INFO] Triton not available")
# Out:
# Project root: c:\Users\PC\Desktop\fish-speech
#
# ============================================================
# ENVIRONMENT CHECK
# ============================================================
# Python: 3.10.11
# PyTorch: 2.9.1+cu130
# CUDA Available: True
# GPU: NVIDIA GeForce RTX 5070 Ti
# VRAM: 15.9 GB
# [WARN] Low VRAM - reduce batch size
# [INFO] Triton not available

# %%
# Cell 2: Fix Protobuf Compatibility
# The protobuf files were generated with protobuf 6.x which includes runtime_version
# If you have an older protobuf version, we need to patch the files or upgrade

import google.protobuf

print("Checking protobuf version...")
protobuf_version = google.protobuf.__version__
print(f"Installed protobuf: {protobuf_version}")

# Check if runtime_version exists
try:
    from google.protobuf import runtime_version
    print("[OK] Protobuf version is compatible (has runtime_version)")
    PROTOBUF_FIXED = True
except ImportError:
    print(f"[WARN] Protobuf {protobuf_version} doesn't have runtime_version")
    print("[INFO] Patching protobuf file for compatibility...")
    
    # Patch the protobuf file to work with older versions
    pb2_file = project_root / "fish_speech" / "datasets" / "protos" / "text_data_pb2.py"
    
    if pb2_file.exists():
        content = pb2_file.read_text(encoding='utf-8')
        
        # Check if already patched
        if "# Compatibility shim" in content or "try:" in content.split('\n')[7:12]:
            print("[INFO] File already patched")
            PROTOBUF_FIXED = True
        elif "from google.protobuf import runtime_version as _runtime_version" in content:
            # Replace the import and validation with try/except
            old_import = """from google.protobuf import descriptor as _descriptor
from google.protobuf import descriptor_pool as _descriptor_pool
from google.protobuf import runtime_version as _runtime_version
from google.protobuf import symbol_database as _symbol_database
from google.protobuf.internal import builder as _builder
_runtime_version.ValidateProtobufRuntimeVersion(
    _runtime_version.Domain.PUBLIC,
    6,
    31,
    1,
    '',
    'text-data.proto'
)"""
            
            new_import = """from google.protobuf import descriptor as _descriptor
from google.protobuf import descriptor_pool as _descriptor_pool
# Compatibility shim for older protobuf versions
try:
    from google.protobuf import runtime_version as _runtime_version
    _runtime_version.ValidateProtobufRuntimeVersion(
        _runtime_version.Domain.PUBLIC,
        6,
        31,
        1,
        '',
        'text-data.proto'
    )
except ImportError:
    # Older protobuf versions don't have runtime_version - skip validation
    pass
from google.protobuf import symbol_database as _symbol_database
from google.protobuf.internal import builder as _builder"""
            
            if old_import in content:
                content = content.replace(old_import, new_import)
                pb2_file.write_text(content, encoding='utf-8')
                print(f"[OK] Patched {pb2_file.name} for compatibility")
                PROTOBUF_FIXED = True
            else:
                print("[WARN] Could not find exact pattern to patch")
                PROTOBUF_FIXED = False
        else:
            print("[INFO] File doesn't need patching or already patched")
            PROTOBUF_FIXED = True
    else:
        print(f"[ERROR] Protobuf file not found: {pb2_file}")
        PROTOBUF_FIXED = False
    
    # Try importing again
    if PROTOBUF_FIXED:
        try:
            from fish_speech.datasets.protos.text_data_pb2 import SampledData
            print("[OK] Protobuf import successful after patching")
            PROTOBUF_FIXED = True
        except Exception as e:
            print(f"[ERROR] Still can't import protobuf: {e}")
            print("[SUGGESTION] Upgrade protobuf: pip install --upgrade protobuf>=6.0.0")
            PROTOBUF_FIXED = False

if not PROTOBUF_FIXED:
    print("\n[ACTION REQUIRED] Please run:")
    print("  pip install --upgrade protobuf>=6.0.0")
    print("Then restart this notebook.")
else:
    print("\n[OK] Protobuf compatibility check passed - ready to proceed!")
# Out:
# Checking protobuf version...
# Installed protobuf: 3.20.3
# [WARN] Protobuf 3.20.3 doesn't have runtime_version
# [INFO] Patching protobuf file for compatibility...
# [INFO] File already patched
# [OK] Protobuf import successful after patching
#
# [OK] Protobuf compatibility check passed - ready to proceed!

# %%
# Cell 2: Configuration - EDIT THESE VALUES

# Dataset paths
DATASET_NAME = "neymar"
DATASET_DIR = Path("neymar_Dataset_enhanced")
METADATA_CSV = DATASET_DIR / "metadata.csv"
WAVS_DIR = DATASET_DIR / "wavs"

# Output paths
DATA_DIR = Path("data")
SPEAKER_DIR = DATA_DIR / DATASET_NAME
PROTOS_DIR = DATA_DIR / "protos"

# Model paths
CHECKPOINT_PATH = Path("checkpoints/openaudio-s1-mini")
CODEC_PATH = CHECKPOINT_PATH / "codec.pth"

# Training config
PROJECT_NAME = f"{DATASET_NAME}_finetune"
MAX_STEPS = 1000
BATCH_SIZE = 4
LEARNING_RATE = 1e-4
VAL_CHECK_INTERVAL = 100
LORA_R = 8
LORA_ALPHA = 16

# Output model
OUTPUT_MODEL = Path(f"checkpoints/openaudio-s1-mini-{DATASET_NAME}")

# Verify paths
print("="*60)
print("CONFIGURATION")
print("="*60)
print(f"Dataset: {DATASET_DIR}")
print(f"Output: {OUTPUT_MODEL}")
print(f"Training: {MAX_STEPS} steps, batch={BATCH_SIZE}, lr={LEARNING_RATE}")
print(f"LoRA: r={LORA_R}, alpha={LORA_ALPHA}")

assert DATASET_DIR.exists(), f"Dataset not found: {DATASET_DIR}"
assert CHECKPOINT_PATH.exists(), f"Model not found: {CHECKPOINT_PATH}"

wav_count = len(list(WAVS_DIR.glob("*.wav"))) if WAVS_DIR.exists() else 0
print(f"\n[OK] Found {wav_count} audio files")
# Out:
# ============================================================
# CONFIGURATION
# ============================================================
# Dataset: neymar_Dataset_enhanced
# Output: checkpoints\openaudio-s1-mini-neymar
# Training: 1000 steps, batch=4, lr=0.0001
# LoRA: r=8, alpha=16
#
# [OK] Found 743 audio files

# %%
# Cell 3: Analyze Dataset
import pandas as pd
import soundfile as sf
from IPython.display import Audio, display

# Parse LJSpeech metadata
with open(METADATA_CSV, 'r', encoding='utf-8') as f:
    lines = f.readlines()

data = []
for line in lines:
    parts = line.strip().split('|')
    if len(parts) >= 2:
        data.append({'id': parts[0], 'text': parts[1]})

df = pd.DataFrame(data)
print(f"Entries: {len(df)}")

# Text stats
df['text_length'] = df['text'].str.len()
print(f"Text length: {df['text_length'].min()}-{df['text_length'].max()} chars")

# Audio stats
total_duration = 0
for idx, row in df.iterrows():
    wav_path = WAVS_DIR / f"{row['id']}.wav"
    if wav_path.exists():
        try:
            info = sf.info(str(wav_path))
            total_duration += info.duration
        except:
            pass

print(f"Total duration: {total_duration/60:.1f} minutes")

# Sample
display(df.head())
sample_wav = WAVS_DIR / f"{df.iloc[0]['id']}.wav"
if sample_wav.exists():
    display(Audio(filename=str(sample_wav)))
# Out:
# Entries: 742
# Text length: 25-295 chars
# Total duration: 77.4 minutes
#         id                                               text  text_length
# 0  NEY0001  Porque dÃ³i muito, nÃ©? Ter o sonho e ir embor...           81
# 1  NEY0002  Eu preferia muito bem nÃ£o ter feito o gol, es...          159
# 2  NEY0003  A importÃ¢ncia do Instituto pra mim Ã© muito g...           52
# 3  NEY0004  o Instituto Ã© o gol da minha carreira mais im...           72
# 4  NEY0005  EntÃ£o, isso pra mim Ã© um orgulho muito grand...          137
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Cell 4: Convert to Fish Speech format
print("Converting dataset...")

SPEAKER_DIR.mkdir(parents=True, exist_ok=True)

converted = 0
for idx, row in df.iterrows():
    file_id = row['id']
    text = row['text']
    
    src_wav = WAVS_DIR / f"{file_id}.wav"
    dst_wav = SPEAKER_DIR / f"{file_id}.wav"
    dst_lab = SPEAKER_DIR / f"{file_id}.lab"
    
    if not src_wav.exists():
        continue
    
    if not dst_wav.exists():
        shutil.copy2(src_wav, dst_wav)
    
    dst_lab.write_text(text, encoding='utf-8')
    converted += 1

print(f"Converted {converted} files to {SPEAKER_DIR}")

# Verify
wav_count = len(list(SPEAKER_DIR.glob("*.wav")))
lab_count = len(list(SPEAKER_DIR.glob("*.lab")))
print(f"Verification: {wav_count} WAV, {lab_count} LAB")
# Out:
# Converting dataset...
# Converted 742 files to data\neymar
# Verification: 742 WAV, 742 LAB

# %%
# Cell 5: Extract VQ tokens
print("Extracting VQ tokens (this takes several minutes)...")

cmd = [
    sys.executable,
    "tools/vqgan/extract_vq.py",
    str(DATA_DIR),
    "--num-workers", "1",
    "--batch-size", "16",
    "--config-name", "modded_dac_vq",
    "--checkpoint-path", str(CODEC_PATH),
]

start = time.time()
result = subprocess.run(cmd, capture_output=True, text=True, encoding='utf-8', errors='replace')
elapsed = time.time() - start

if result.returncode != 0:
    print(f"[ERROR] VQ extraction failed")
    print(result.stderr[-1500:])
else:
    npy_files = list(SPEAKER_DIR.glob("*.npy"))
    print(f"[OK] Generated {len(npy_files)} .npy files in {elapsed:.0f}s")
# Out:
# Extracting VQ tokens (this takes several minutes)...
# [OK] Generated 742 .npy files in 8s

# %%
# Cell 6: Build protobuf dataset
print("Building protobuf dataset...")

PROTOS_DIR.mkdir(parents=True, exist_ok=True)

cmd = [
    sys.executable,
    "tools/llama/build_dataset.py",
    "--input", str(DATA_DIR),
    "--output", str(PROTOS_DIR),
    "--text-extension", ".lab",
    "--num-workers", "4",
]

result = subprocess.run(cmd, capture_output=True, text=True, encoding='utf-8', errors='replace')

if result.returncode != 0:
    print(f"[ERROR] Dataset build failed")
    print(result.stderr[-1500:])
else:
    proto_files = list(PROTOS_DIR.iterdir())
    total_size = sum(f.stat().st_size for f in proto_files if f.is_file())
    print(f"[OK] Built {len(proto_files)} files ({total_size/1024/1024:.1f} MB)")
# Out:
# Building protobuf dataset...
# [OK] Built 1 files (3.8 MB)

# %%
# Cell 7: LoRA Finetuning
print(f"Starting LoRA finetuning: {MAX_STEPS} steps...")

cmd = [
    sys.executable,
    "fish_speech/train.py",
    "--config-name", "text2semantic_finetune",
    f"project={PROJECT_NAME}",
    f"trainer.max_steps={MAX_STEPS}",
    f"trainer.val_check_interval={VAL_CHECK_INTERVAL}",
    f"data.batch_size={BATCH_SIZE}",
    f"model.optimizer.lr={LEARNING_RATE}",
    f"+lora@model.model.lora_config=r_{LORA_R}_alpha_{LORA_ALPHA}",
]

# Fix: Delete checkpoint directory to prevent auto-resume
# The training code calls get_latest_checkpoint() unconditionally
ckpt_dir = project_root / f"results/{PROJECT_NAME}/checkpoints"
if ckpt_dir.exists():
    print(f"[INFO] Removing existing checkpoints to start fresh training...")
    shutil.rmtree(ckpt_dir)


# Windows: use single device strategy (no DDP)
if platform.system() == 'Windows':
    cmd.append("trainer.strategy=auto")
    cmd.append("trainer.devices=1")
start = time.time()
process = subprocess.Popen(cmd, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True, encoding='utf-8', errors='replace', bufsize=1)

# Safely iterate over stdout
if process.stdout is not None:
    for line in process.stdout:
        print(line, end='')
else:
    # Fallback: wait and get output
    stdout, stderr = process.communicate()
    if stdout:
        print(stdout)
    if stderr:
        print(stderr, file=sys.stderr)

process.wait()
elapsed = time.time() - start

if process.returncode == 0:
    print(f"\n[OK] Training completed in {elapsed/60:.1f} minutes")
else:
    print(f"\n[ERROR] Training failed")
# Out:
# Starting LoRA finetuning: 1000 steps...
# [INFO] Removing existing checkpoints to start fresh training...
# [2025-12-19 05:57:59,290][__main__][INFO] - [rank: 0] Instantiating datamodule <fish_speech.datasets.semantic.SemanticDataModule>
# [2025-12-19 05:57:59,462][datasets][INFO] - PyTorch version 2.9.1+cu130 available.
# [2025-12-19 05:58:00,019][__main__][INFO] - [rank: 0] Instantiating model <fish_speech.models.text2semantic.lit_module.TextToSemantic>
# 2025-12-19 05:58:00.029 | INFO     | fish_speech.models.text2semantic.llama:from_pretrained:416 - Override max_seq_len to 4096
# 2025-12-19 05:58:00.170 | INFO     | fish_speech.models.text2semantic.llama:from_pretrained:432 - Loading model from checkpoints/openaudio-s1-mini, config: DualARModelArgs(model_type='dual_ar', vocab_size=155776, n_layer=28, n_head=16, dim=1024, intermediate_size=3072, n_local_heads=8, head_dim=128, rope_base=1000000, norm_eps=1e-06, max_seq_len=4096, dropout=0.0, tie_word_embeddings=False, attention_qkv_bias=False, attention_o_bias=False, attention_qk_norm=True, codebook_size=4096, num_codebooks=10, use_gradient_checkpointing=True, initializer_range=0.03125, is_reward_model=False, scale_codebook_embeddings=True, n_fast_layer=4, fast_dim=1024, fast_n_head=16, fast_n_local_heads=8, fast_head_dim=64, fast_intermediate_size=3072, fast_attention_qkv_bias=False, fast_attention_qk_norm=False, fast_attention_o_bias=False)
# 2025-12-19 05:58:04.472 | INFO     | fish_speech.models.text2semantic.llama:from_pretrained:494 - Loaded weights with error: <All keys matched successfully>
# 2025-12-19 05:58:08.233 | INFO     | fish_speech.models.text2semantic.llama:from_pretrained:498 - LoRA setup: LoraConfig(r=8, lora_alpha=16, lora_dropout=0.01)
# [2025-12-19 05:58:08,235][__main__][INFO] - [rank: 0] Instantiating callbacks...
# [2025-12-19 05:58:08,235][fish_speech.utils.instantiators][INFO] - [rank: 0] Instantiating callback <lightning.pytorch.callbacks.ModelCheckpoint>
# [2025-12-19 05:58:08,238][fish_speech.utils.instantiators][INFO] - [rank: 0] Instantiating callback <lightning.pytorch.callbacks.ModelSummary>
# [2025-12-19 05:58:08,238][fish_speech.utils.instantiators][INFO] - [rank: 0] Instantiating callback <lightning.pytorch.callbacks.LearningRateMonitor>
# [2025-12-19 05:58:08,238][fish_speech.utils.instantiators][INFO] - [rank: 0] Instantiating callback <fish_speech.callbacks.GradNormMonitor>
# [2025-12-19 05:58:08,239][__main__][INFO] - [rank: 0] Instantiating loggers...
# [2025-12-19 05:58:08,239][fish_speech.utils.instantiators][INFO] - [rank: 0] Instantiating logger <lightning.pytorch.loggers.tensorboard.TensorBoardLogger>
# [2025-12-19 05:58:08,241][__main__][INFO] - [rank: 0] Instantiating trainer <lightning.pytorch.trainer.Trainer>
# Trainer already configured with model summary callbacks: [<class 'lightning.pytorch.callbacks.model_summary.ModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# [2025-12-19 05:58:08,265][__main__][INFO] - [rank: 0] Logging hyperparameters!
# [2025-12-19 05:58:08,318][__main__][INFO] - [rank: 0] Starting training!
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [2025-12-19 05:58:08,936][fish_speech.models.text2semantic.lit_module][INFO] - [rank: 0] Set weight decay: 0 for 492 parameters
# [2025-12-19 05:58:08,936][fish_speech.models.text2semantic.lit_module][INFO] - [rank: 0] Set weight decay: 0.0 for 125 parameters
#
#    | Name                      | Type              | Params | Mode
# -------------------------------------------------------------------------
# 0  | model                     | DualARTransformer | 868 M  | train
# 1  | model.embeddings          | Embedding         | 160 M  | train
# 2  | model.codebook_embeddings | Embedding         | 42.3 M | train
# 3  | model.layers              | ModuleList        | 445 M  | train
# 4  | model.norm                | RMSNorm           | 1.0 K  | train
# 5  | model.output              | Linear            | 160 M  | train
# 6  | model.fast_project_in     | Identity          | 0      | train
# 7  | model.fast_embeddings     | Embedding         | 4.2 M  | train
# 8  | model.fast_layers         | ModuleList        | 50.9 M | train
# 9  | model.fast_norm           | RMSNorm           | 1.0 K  | train
# 10 | model.fast_output         | Linear            | 4.2 M  | train
# -------------------------------------------------------------------------
# 8.1 M     Trainable params
# 860 M     Non-trainable params
# 868 M     Total params
# 1,736.481 Total estimated model params size (MB)
# 549       Modules in train mode
# 0         Modules in eval mode
#
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Sanity Checking DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Sanity Checking DataLoader 0:  50%|█████     | 1/2 [00:04<00:04,  0.22it/s]
# Sanity Checking DataLoader 0: 100%|██████████| 2/2 [00:08<00:00,  0.24it/s]
#
#
# Training: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Epoch 0:   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 0:   0%|          | 1/1000 [00:16<4:30:38,  0.06it/s]
# Epoch 0:   0%|          | 1/1000 [00:16<4:30:38,  0.06it/s, v_num=4, train/loss=23.00, train/top_5_accuracy=0.00118]
# Epoch 0:   0%|          | 2/1000 [00:28<3:53:31,  0.07it/s, v_num=4, train/loss=23.00, train/top_5_accuracy=0.00118]
# Epoch 0:   0%|          | 2/1000 [00:28<3:56:38,  0.07it/s, v_num=4, train/loss=23.00, train/top_5_accuracy=0.00122]
# Epoch 0:   0%|          | 3/1000 [00:41<3:47:52,  0.07it/s, v_num=4, train/loss=23.00, train/top_5_accuracy=0.00122]
# Epoch 0:   0%|          | 3/1000 [00:41<3:50:16,  0.07it/s, v_num=4, train/loss=23.00, train/top_5_accuracy=0.00117]
# Epoch 0:   0%|          | 4/1000 [00:54<3:45:21,  0.07it/s, v_num=4, train/loss=23.00, train/top_5_accuracy=0.00117]
# Epoch 0:   0%|          | 4/1000 [00:54<3:47:07,  0.07it/s, v_num=4, train/loss=23.00, train/top_5_accuracy=0.00104]
# Epoch 0:   0%|          | 5/1000 [01:07<3:43:25,  0.07it/s, v_num=4, train/loss=23.00, train/top_5_accuracy=0.00104]
# Epoch 0:   0%|          | 5/1000 [01:07<3:44:42,  0.07it/s, v_num=4, train/loss=23.00, train/top_5_accuracy=0.00116]
# Epoch 0:   1%|          | 6/1000 [01:19<3:39:35,  0.08it/s, v_num=4, train/loss=23.00, train/top_5_accuracy=0.00116]
# Epoch 0:   1%|          | 6/1000 [01:19<3:40:42,  0.08it/s, v_num=4, train/loss=23.00, train/top_5_accuracy=0.00101]
# Epoch 0:   1%|          | 7/1000 [01:32<3:38:52,  0.08it/s, v_num=4, train/loss=23.00, train/top_5_accuracy=0.00101]
# Epoch 0:   1%|          | 7/1000 [01:33<3:39:54,  0.08it/s, v_num=4, train/loss=23.00, train/top_5_accuracy=0.00132]
# Epoch 0:   1%|          | 8/1000 [01:44<3:35:43,  0.08it/s, v_num=4, train/loss=23.00, train/top_5_accuracy=0.00132]
# Epoch 0:   1%|          | 8/1000 [01:44<3:36:27,  0.08it/s, v_num=4, train/loss=23.00, train/top_5_accuracy=0.00121]
# Epoch 0:   1%|          | 9/1000 [01:57<3:35:43,  0.08it/s, v_num=4, train/loss=23.00, train/top_5_accuracy=0.00121]
# Epoch 0:   1%|          | 9/1000 [01:57<3:36:24,  0.08it/s, v_num=4, train/loss=22.90, train/top_5_accuracy=0.00113]
# Epoch 0:   1%|          | 10/1000 [02:10<3:35:38,  0.08it/s, v_num=4, train/loss=22.90, train/top_5_accuracy=0.00113]
# Epoch 0:   1%|          | 10/1000 [02:11<3:36:20,  0.08it/s, v_num=4, train/loss=22.80, train/top_5_accuracy=0.00118]
# Epoch 0:   1%|          | 11/1000 [02:23<3:35:18,  0.08it/s, v_num=4, train/loss=22.80, train/top_5_accuracy=0.00118]
# Epoch 0:   1%|          | 11/1000 [02:24<3:35:54,  0.08it/s, v_num=4, train/loss=22.80, train/top_5_accuracy=0.00125]
# Epoch 0:   1%|          | 12/1000 [02:35<3:34:00,  0.08it/s, v_num=4, train/loss=22.80, train/top_5_accuracy=0.00125]
# Epoch 0:   1%|          | 12/1000 [02:36<3:34:30,  0.08it/s, v_num=4, train/loss=22.80, train/top_5_accuracy=0.00131]
# Epoch 0:   1%|▏         | 13/1000 [02:47<3:32:18,  0.08it/s, v_num=4, train/loss=22.80, train/top_5_accuracy=0.00131]
# Epoch 0:   1%|▏         | 13/1000 [02:48<3:32:48,  0.08it/s, v_num=4, train/loss=22.50, train/top_5_accuracy=0.00103]
# Epoch 0:   1%|▏         | 14/1000 [03:01<3:32:31,  0.08it/s, v_num=4, train/loss=22.50, train/top_5_accuracy=0.00103]
# Epoch 0:   1%|▏         | 14/1000 [03:01<3:33:00,  0.08it/s, v_num=4, train/loss=22.60, train/top_5_accuracy=0.0012]
# Epoch 0:   2%|▏         | 15/1000 [03:13<3:31:42,  0.08it/s, v_num=4, train/loss=22.60, train/top_5_accuracy=0.0012]
# Epoch 0:   2%|▏         | 15/1000 [03:13<3:32:06,  0.08it/s, v_num=4, train/loss=22.50, train/top_5_accuracy=0.00127]
# Epoch 0:   2%|▏         | 16/1000 [03:26<3:31:49,  0.08it/s, v_num=4, train/loss=22.50, train/top_5_accuracy=0.00127]
# Epoch 0:   2%|▏         | 16/1000 [03:27<3:32:14,  0.08it/s, v_num=4, train/loss=22.50, train/top_5_accuracy=0.00108]
# Epoch 0:   2%|▏         | 17/1000 [03:38<3:30:17,  0.08it/s, v_num=4, train/loss=22.50, train/top_5_accuracy=0.00108]
# Epoch 0:   2%|▏         | 17/1000 [03:38<3:30:40,  0.08it/s, v_num=4, train/loss=22.40, train/top_5_accuracy=0.00104]
# Epoch 0:   2%|▏         | 18/1000 [03:49<3:28:59,  0.08it/s, v_num=4, train/loss=22.40, train/top_5_accuracy=0.00104]
# Epoch 0:   2%|▏         | 18/1000 [03:50<3:29:22,  0.08it/s, v_num=4, train/loss=22.20, train/top_5_accuracy=0.0012]
# Epoch 0:   2%|▏         | 19/1000 [04:03<3:29:07,  0.08it/s, v_num=4, train/loss=22.20, train/top_5_accuracy=0.0012]
# Epoch 0:   2%|▏         | 19/1000 [04:03<3:29:28,  0.08it/s, v_num=4, train/loss=22.20, train/top_5_accuracy=0.00126]
# Epoch 0:   2%|▏         | 20/1000 [04:16<3:29:14,  0.08it/s, v_num=4, train/loss=22.20, train/top_5_accuracy=0.00126]
# Epoch 0:   2%|▏         | 20/1000 [04:16<3:29:32,  0.08it/s, v_num=4, train/loss=22.20, train/top_5_accuracy=0.00119]
# Epoch 0:   2%|▏         | 21/1000 [04:27<3:28:08,  0.08it/s, v_num=4, train/loss=22.20, train/top_5_accuracy=0.00119]
# Epoch 0:   2%|▏         | 21/1000 [04:28<3:28:28,  0.08it/s, v_num=4, train/loss=22.00, train/top_5_accuracy=0.00114]
# Epoch 0:   2%|▏         | 22/1000 [04:41<3:28:14,  0.08it/s, v_num=4, train/loss=22.00, train/top_5_accuracy=0.00114]
# Epoch 0:   2%|▏         | 22/1000 [04:41<3:28:33,  0.08it/s, v_num=4, train/loss=22.20, train/top_5_accuracy=0.00124]
# Epoch 0:   2%|▏         | 23/1000 [04:53<3:27:45,  0.08it/s, v_num=4, train/loss=22.20, train/top_5_accuracy=0.00124]
# Epoch 0:   2%|▏         | 23/1000 [04:53<3:28:03,  0.08it/s, v_num=4, train/loss=22.00, train/top_5_accuracy=0.00125]
# Epoch 0:   2%|▏         | 24/1000 [05:05<3:26:47,  0.08it/s, v_num=4, train/loss=22.00, train/top_5_accuracy=0.00125]
# Epoch 0:   2%|▏         | 24/1000 [05:05<3:27:05,  0.08it/s, v_num=4, train/loss=21.80, train/top_5_accuracy=0.00121]
# Epoch 0:   2%|▎         | 25/1000 [05:18<3:26:47,  0.08it/s, v_num=4, train/loss=21.80, train/top_5_accuracy=0.00121]
# Epoch 0:   2%|▎         | 25/1000 [05:18<3:27:04,  0.08it/s, v_num=4, train/loss=21.80, train/top_5_accuracy=0.00114]
# Epoch 0:   3%|▎         | 26/1000 [05:31<3:26:52,  0.08it/s, v_num=4, train/loss=21.80, train/top_5_accuracy=0.00114]
# Epoch 0:   3%|▎         | 26/1000 [05:31<3:27:07,  0.08it/s, v_num=4, train/loss=21.50, train/top_5_accuracy=0.00133]
# Epoch 0:   3%|▎         | 27/1000 [05:42<3:25:57,  0.08it/s, v_num=4, train/loss=21.50, train/top_5_accuracy=0.00133]
# Epoch 0:   3%|▎         | 27/1000 [05:43<3:26:12,  0.08it/s, v_num=4, train/loss=21.60, train/top_5_accuracy=0.00125]
# Epoch 0:   3%|▎         | 28/1000 [05:56<3:26:10,  0.08it/s, v_num=4, train/loss=21.60, train/top_5_accuracy=0.00125]
# Epoch 0:   3%|▎         | 28/1000 [05:56<3:26:25,  0.08it/s, v_num=4, train/loss=21.50, train/top_5_accuracy=0.00116]
# Epoch 0:   3%|▎         | 29/1000 [06:09<3:26:11,  0.08it/s, v_num=4, train/loss=21.50, train/top_5_accuracy=0.00116]
# Epoch 0:   3%|▎         | 29/1000 [06:09<3:26:26,  0.08it/s, v_num=4, train/loss=21.20, train/top_5_accuracy=0.00146]
# Epoch 0:   3%|▎         | 30/1000 [06:22<3:25:52,  0.08it/s, v_num=4, train/loss=21.20, train/top_5_accuracy=0.00146]
# Epoch 0:   3%|▎         | 30/1000 [06:22<3:26:06,  0.08it/s, v_num=4, train/loss=21.20, train/top_5_accuracy=0.00113]
# Epoch 0:   3%|▎         | 31/1000 [06:34<3:25:24,  0.08it/s, v_num=4, train/loss=21.20, train/top_5_accuracy=0.00113]
# Epoch 0:   3%|▎         | 31/1000 [06:34<3:25:38,  0.08it/s, v_num=4, train/loss=21.50, train/top_5_accuracy=0.00123]
# Epoch 0:   3%|▎         | 32/1000 [06:46<3:25:08,  0.08it/s, v_num=4, train/loss=21.50, train/top_5_accuracy=0.00123]
# Epoch 0:   3%|▎         | 32/1000 [06:47<3:25:20,  0.08it/s, v_num=4, train/loss=21.00, train/top_5_accuracy=0.0011]
# Epoch 0:   3%|▎         | 33/1000 [06:59<3:24:51,  0.08it/s, v_num=4, train/loss=21.00, train/top_5_accuracy=0.0011]
# Epoch 0:   3%|▎         | 33/1000 [06:59<3:25:04,  0.08it/s, v_num=4, train/loss=21.00, train/top_5_accuracy=0.00119]
# Epoch 0:   3%|▎         | 34/1000 [07:12<3:24:53,  0.08it/s, v_num=4, train/loss=21.00, train/top_5_accuracy=0.00119]
# Epoch 0:   3%|▎         | 34/1000 [07:13<3:25:05,  0.08it/s, v_num=4, train/loss=21.00, train/top_5_accuracy=0.00124]
# Epoch 0:   4%|▎         | 35/1000 [07:25<3:24:31,  0.08it/s, v_num=4, train/loss=21.00, train/top_5_accuracy=0.00124]
# Epoch 0:   4%|▎         | 35/1000 [07:25<3:24:43,  0.08it/s, v_num=4, train/loss=21.00, train/top_5_accuracy=0.00118]
# Epoch 0:   4%|▎         | 36/1000 [07:37<3:24:16,  0.08it/s, v_num=4, train/loss=21.00, train/top_5_accuracy=0.00118]
# Epoch 0:   4%|▎         | 36/1000 [07:38<3:24:27,  0.08it/s, v_num=4, train/loss=20.80, train/top_5_accuracy=0.00113]
# Epoch 0:   4%|▎         | 37/1000 [07:51<3:24:24,  0.08it/s, v_num=4, train/loss=20.80, train/top_5_accuracy=0.00113]
# Epoch 0:   4%|▎         | 37/1000 [07:51<3:24:33,  0.08it/s, v_num=4, train/loss=21.20, train/top_5_accuracy=0.00111]
# Epoch 0:   4%|▍         | 38/1000 [08:03<3:24:05,  0.08it/s, v_num=4, train/loss=21.20, train/top_5_accuracy=0.00111]
# Epoch 0:   4%|▍         | 38/1000 [08:04<3:24:14,  0.08it/s, v_num=4, train/loss=20.50, train/top_5_accuracy=0.00115]
# Epoch 0:   4%|▍         | 39/1000 [08:16<3:23:51,  0.08it/s, v_num=4, train/loss=20.50, train/top_5_accuracy=0.00115]
# Epoch 0:   4%|▍         | 39/1000 [08:16<3:24:01,  0.08it/s, v_num=4, train/loss=20.80, train/top_5_accuracy=0.00108]
# Epoch 0:   4%|▍         | 40/1000 [08:28<3:23:32,  0.08it/s, v_num=4, train/loss=20.80, train/top_5_accuracy=0.00108]
# Epoch 0:   4%|▍         | 40/1000 [08:29<3:23:40,  0.08it/s, v_num=4, train/loss=20.50, train/top_5_accuracy=0.00136]
# Epoch 0:   4%|▍         | 41/1000 [08:40<3:22:51,  0.08it/s, v_num=4, train/loss=20.50, train/top_5_accuracy=0.00136]
# Epoch 0:   4%|▍         | 41/1000 [08:40<3:23:00,  0.08it/s, v_num=4, train/loss=20.50, train/top_5_accuracy=0.00135]
# Epoch 0:   4%|▍         | 42/1000 [08:52<3:22:31,  0.08it/s, v_num=4, train/loss=20.50, train/top_5_accuracy=0.00135]
# Epoch 0:   4%|▍         | 42/1000 [08:53<3:22:41,  0.08it/s, v_num=4, train/loss=20.20, train/top_5_accuracy=0.0013]
# Epoch 0:   4%|▍         | 43/1000 [09:05<3:22:28,  0.08it/s, v_num=4, train/loss=20.20, train/top_5_accuracy=0.0013]
# Epoch 0:   4%|▍         | 43/1000 [09:06<3:22:37,  0.08it/s, v_num=4, train/loss=20.20, train/top_5_accuracy=0.00116]
# Epoch 0:   4%|▍         | 44/1000 [09:17<3:22:03,  0.08it/s, v_num=4, train/loss=20.20, train/top_5_accuracy=0.00116]
# Epoch 0:   4%|▍         | 44/1000 [09:18<3:22:11,  0.08it/s, v_num=4, train/loss=20.00, train/top_5_accuracy=0.00137]
# Epoch 0:   4%|▍         | 45/1000 [09:30<3:21:39,  0.08it/s, v_num=4, train/loss=20.00, train/top_5_accuracy=0.00137]
# Epoch 0:   4%|▍         | 45/1000 [09:30<3:21:49,  0.08it/s, v_num=4, train/loss=19.80, train/top_5_accuracy=0.00142]
# Epoch 0:   5%|▍         | 46/1000 [09:42<3:21:20,  0.08it/s, v_num=4, train/loss=19.80, train/top_5_accuracy=0.00142]
# Epoch 0:   5%|▍         | 46/1000 [09:42<3:21:27,  0.08it/s, v_num=4, train/loss=20.00, train/top_5_accuracy=0.00159]
# Epoch 0:   5%|▍         | 47/1000 [09:54<3:20:57,  0.08it/s, v_num=4, train/loss=20.00, train/top_5_accuracy=0.00159]
# Epoch 0:   5%|▍         | 47/1000 [09:55<3:21:06,  0.08it/s, v_num=4, train/loss=20.20, train/top_5_accuracy=0.00143]
# Epoch 0:   5%|▍         | 48/1000 [10:07<3:20:56,  0.08it/s, v_num=4, train/loss=20.20, train/top_5_accuracy=0.00143]
# Epoch 0:   5%|▍         | 48/1000 [10:08<3:21:03,  0.08it/s, v_num=4, train/loss=19.80, train/top_5_accuracy=0.00138]
# Epoch 0:   5%|▍         | 49/1000 [10:19<3:20:24,  0.08it/s, v_num=4, train/loss=19.80, train/top_5_accuracy=0.00138]
# Epoch 0:   5%|▍         | 49/1000 [10:20<3:20:33,  0.08it/s, v_num=4, train/loss=19.60, train/top_5_accuracy=0.0015]
# Epoch 0:   5%|▌         | 50/1000 [10:31<3:20:06,  0.08it/s, v_num=4, train/loss=19.60, train/top_5_accuracy=0.0015]
# Epoch 0:   5%|▌         | 50/1000 [10:32<3:20:14,  0.08it/s, v_num=4, train/loss=19.60, train/top_5_accuracy=0.00137]
# Epoch 0:   5%|▌         | 51/1000 [10:43<3:19:33,  0.08it/s, v_num=4, train/loss=19.60, train/top_5_accuracy=0.00137]
# Epoch 0:   5%|▌         | 51/1000 [10:43<3:19:39,  0.08it/s, v_num=4, train/loss=19.50, train/top_5_accuracy=0.00158]
# Epoch 0:   5%|▌         | 52/1000 [10:55<3:19:12,  0.08it/s, v_num=4, train/loss=19.50, train/top_5_accuracy=0.00158]
# Epoch 0:   5%|▌         | 52/1000 [10:56<3:19:19,  0.08it/s, v_num=4, train/loss=19.50, train/top_5_accuracy=0.00164]
# Epoch 0:   5%|▌         | 53/1000 [11:08<3:19:07,  0.08it/s, v_num=4, train/loss=19.50, train/top_5_accuracy=0.00164]
# Epoch 0:   5%|▌         | 53/1000 [11:09<3:19:14,  0.08it/s, v_num=4, train/loss=19.50, train/top_5_accuracy=0.00158]
# Epoch 0:   5%|▌         | 54/1000 [11:21<3:18:51,  0.08it/s, v_num=4, train/loss=19.50, train/top_5_accuracy=0.00158]
# Epoch 0:   5%|▌         | 54/1000 [11:21<3:18:58,  0.08it/s, v_num=4, train/loss=19.50, train/top_5_accuracy=0.00172]
# Epoch 0:   6%|▌         | 55/1000 [11:33<3:18:35,  0.08it/s, v_num=4, train/loss=19.50, train/top_5_accuracy=0.00172]
# Epoch 0:   6%|▌         | 55/1000 [11:33<3:18:41,  0.08it/s, v_num=4, train/loss=19.20, train/top_5_accuracy=0.00182]
# Epoch 0:   6%|▌         | 56/1000 [11:45<3:18:17,  0.08it/s, v_num=4, train/loss=19.20, train/top_5_accuracy=0.00182]
# Epoch 0:   6%|▌         | 56/1000 [11:46<3:18:24,  0.08it/s, v_num=4, train/loss=19.00, train/top_5_accuracy=0.00189]
# Epoch 0:   6%|▌         | 57/1000 [11:58<3:18:11,  0.08it/s, v_num=4, train/loss=19.00, train/top_5_accuracy=0.00189]
# Epoch 0:   6%|▌         | 57/1000 [11:59<3:18:17,  0.08it/s, v_num=4, train/loss=19.00, train/top_5_accuracy=0.00194]
# Epoch 0:   6%|▌         | 58/1000 [12:10<3:17:45,  0.08it/s, v_num=4, train/loss=19.00, train/top_5_accuracy=0.00194]
# Epoch 0:   6%|▌         | 58/1000 [12:11<3:17:52,  0.08it/s, v_num=4, train/loss=18.80, train/top_5_accuracy=0.00226]
# Epoch 0:   6%|▌         | 59/1000 [12:23<3:17:43,  0.08it/s, v_num=4, train/loss=18.80, train/top_5_accuracy=0.00226]
# Epoch 0:   6%|▌         | 59/1000 [12:24<3:17:49,  0.08it/s, v_num=4, train/loss=18.90, train/top_5_accuracy=0.00214]
# Epoch 0:   6%|▌         | 60/1000 [12:36<3:17:29,  0.08it/s, v_num=4, train/loss=18.90, train/top_5_accuracy=0.00214]
# Epoch 0:   6%|▌         | 60/1000 [12:36<3:17:34,  0.08it/s, v_num=4, train/loss=18.80, train/top_5_accuracy=0.00218]
# Epoch 0:   6%|▌         | 61/1000 [12:48<3:17:11,  0.08it/s, v_num=4, train/loss=18.80, train/top_5_accuracy=0.00218]
# Epoch 0:   6%|▌         | 61/1000 [12:49<3:17:17,  0.08it/s, v_num=4, train/loss=18.60, train/top_5_accuracy=0.00218]
# Epoch 0:   6%|▌         | 62/1000 [13:01<3:17:09,  0.08it/s, v_num=4, train/loss=18.60, train/top_5_accuracy=0.00218]
# Epoch 0:   6%|▌         | 62/1000 [13:02<3:17:15,  0.08it/s, v_num=4, train/loss=18.50, train/top_5_accuracy=0.00226]
# Epoch 0:   6%|▋         | 63/1000 [13:13<3:16:40,  0.08it/s, v_num=4, train/loss=18.50, train/top_5_accuracy=0.00226]
# Epoch 0:   6%|▋         | 63/1000 [13:13<3:16:46,  0.08it/s, v_num=4, train/loss=18.40, train/top_5_accuracy=0.00238]
# Epoch 0:   6%|▋         | 64/1000 [13:26<3:16:31,  0.08it/s, v_num=4, train/loss=18.40, train/top_5_accuracy=0.00238]
# Epoch 0:   6%|▋         | 64/1000 [13:26<3:16:37,  0.08it/s, v_num=4, train/loss=18.20, train/top_5_accuracy=0.00284]
# Epoch 0:   6%|▋         | 65/1000 [13:37<3:16:03,  0.08it/s, v_num=4, train/loss=18.20, train/top_5_accuracy=0.00284]
# Epoch 0:   6%|▋         | 65/1000 [13:38<3:16:09,  0.08it/s, v_num=4, train/loss=18.00, train/top_5_accuracy=0.00299]
# Epoch 0:   7%|▋         | 66/1000 [13:50<3:15:48,  0.08it/s, v_num=4, train/loss=18.00, train/top_5_accuracy=0.00299]
# Epoch 0:   7%|▋         | 66/1000 [13:50<3:15:54,  0.08it/s, v_num=4, train/loss=18.20, train/top_5_accuracy=0.00272]
# Epoch 0:   7%|▋         | 67/1000 [14:02<3:15:33,  0.08it/s, v_num=4, train/loss=18.20, train/top_5_accuracy=0.00272]
# Epoch 0:   7%|▋         | 67/1000 [14:03<3:15:39,  0.08it/s, v_num=4, train/loss=18.00, train/top_5_accuracy=0.00346]
# Epoch 0:   7%|▋         | 68/1000 [14:14<3:15:17,  0.08it/s, v_num=4, train/loss=18.00, train/top_5_accuracy=0.00346]
# Epoch 0:   7%|▋         | 68/1000 [14:15<3:15:23,  0.08it/s, v_num=4, train/loss=17.90, train/top_5_accuracy=0.00346]
# Epoch 0:   7%|▋         | 69/1000 [14:27<3:15:00,  0.08it/s, v_num=4, train/loss=17.90, train/top_5_accuracy=0.00346]
# Epoch 0:   7%|▋         | 69/1000 [14:27<3:15:06,  0.08it/s, v_num=4, train/loss=17.80, train/top_5_accuracy=0.00354]
# Epoch 0:   7%|▋         | 70/1000 [14:39<3:14:43,  0.08it/s, v_num=4, train/loss=17.80, train/top_5_accuracy=0.00354]
# Epoch 0:   7%|▋         | 70/1000 [14:39<3:14:48,  0.08it/s, v_num=4, train/loss=17.80, train/top_5_accuracy=0.00389]
# Epoch 0:   7%|▋         | 71/1000 [14:51<3:14:29,  0.08it/s, v_num=4, train/loss=17.80, train/top_5_accuracy=0.00389]
# Epoch 0:   7%|▋         | 71/1000 [14:52<3:14:35,  0.08it/s, v_num=4, train/loss=17.80, train/top_5_accuracy=0.00369]
# Epoch 0:   7%|▋         | 72/1000 [15:03<3:14:05,  0.08it/s, v_num=4, train/loss=17.80, train/top_5_accuracy=0.00369]
# Epoch 0:   7%|▋         | 72/1000 [15:03<3:14:10,  0.08it/s, v_num=4, train/loss=17.50, train/top_5_accuracy=0.00488]
# Epoch 0:   7%|▋         | 73/1000 [15:16<3:13:52,  0.08it/s, v_num=4, train/loss=17.50, train/top_5_accuracy=0.00488]
# Epoch 0:   7%|▋         | 73/1000 [15:16<3:13:56,  0.08it/s, v_num=4, train/loss=17.50, train/top_5_accuracy=0.00488]
# Epoch 0:   7%|▋         | 74/1000 [15:28<3:13:37,  0.08it/s, v_num=4, train/loss=17.50, train/top_5_accuracy=0.00488]
# Epoch 0:   7%|▋         | 74/1000 [15:28<3:13:42,  0.08it/s, v_num=4, train/loss=17.40, train/top_5_accuracy=0.00558]
# Epoch 0:   8%|▊         | 75/1000 [15:40<3:13:13,  0.08it/s, v_num=4, train/loss=17.40, train/top_5_accuracy=0.00558]
# Epoch 0:   8%|▊         | 75/1000 [15:40<3:13:18,  0.08it/s, v_num=4, train/loss=17.20, train/top_5_accuracy=0.00568]
# Epoch 0:   8%|▊         | 76/1000 [15:52<3:12:59,  0.08it/s, v_num=4, train/loss=17.20, train/top_5_accuracy=0.00568]
# Epoch 0:   8%|▊         | 76/1000 [15:52<3:13:04,  0.08it/s, v_num=4, train/loss=17.20, train/top_5_accuracy=0.00537]
# Epoch 0:   8%|▊         | 77/1000 [16:05<3:12:52,  0.08it/s, v_num=4, train/loss=17.20, train/top_5_accuracy=0.00537]
# Epoch 0:   8%|▊         | 77/1000 [16:05<3:12:56,  0.08it/s, v_num=4, train/loss=17.10, train/top_5_accuracy=0.00623]
# Epoch 0:   8%|▊         | 78/1000 [16:18<3:12:49,  0.08it/s, v_num=4, train/loss=17.10, train/top_5_accuracy=0.00623]
# Epoch 0:   8%|▊         | 78/1000 [16:19<3:12:53,  0.08it/s, v_num=4, train/loss=17.00, train/top_5_accuracy=0.00714]
# Epoch 0:   8%|▊         | 79/1000 [16:32<3:12:47,  0.08it/s, v_num=4, train/loss=17.00, train/top_5_accuracy=0.00714]
# Epoch 0:   8%|▊         | 79/1000 [16:32<3:12:52,  0.08it/s, v_num=4, train/loss=17.10, train/top_5_accuracy=0.00616]
# Epoch 0:   8%|▊         | 80/1000 [16:45<3:12:43,  0.08it/s, v_num=4, train/loss=17.10, train/top_5_accuracy=0.00616]
# Epoch 0:   8%|▊         | 80/1000 [16:45<3:12:48,  0.08it/s, v_num=4, train/loss=16.80, train/top_5_accuracy=0.00723]
# Epoch 0:   8%|▊         | 81/1000 [16:58<3:12:31,  0.08it/s, v_num=4, train/loss=16.80, train/top_5_accuracy=0.00723]
# Epoch 0:   8%|▊         | 81/1000 [16:58<3:12:35,  0.08it/s, v_num=4, train/loss=16.80, train/top_5_accuracy=0.00674]
# Epoch 0:   8%|▊         | 82/1000 [17:11<3:12:28,  0.08it/s, v_num=4, train/loss=16.80, train/top_5_accuracy=0.00674]
# Epoch 0:   8%|▊         | 82/1000 [17:11<3:12:32,  0.08it/s, v_num=4, train/loss=16.80, train/top_5_accuracy=0.00848]
# Epoch 0:   8%|▊         | 83/1000 [17:23<3:12:13,  0.08it/s, v_num=4, train/loss=16.80, train/top_5_accuracy=0.00848]
# Epoch 0:   8%|▊         | 83/1000 [17:24<3:12:17,  0.08it/s, v_num=4, train/loss=16.60, train/top_5_accuracy=0.008]
# Epoch 0:   8%|▊         | 84/1000 [17:36<3:12:03,  0.08it/s, v_num=4, train/loss=16.60, train/top_5_accuracy=0.008]
# Epoch 0:   8%|▊         | 84/1000 [17:37<3:12:07,  0.08it/s, v_num=4, train/loss=16.50, train/top_5_accuracy=0.00934]
# Epoch 0:   8%|▊         | 85/1000 [17:48<3:11:40,  0.08it/s, v_num=4, train/loss=16.50, train/top_5_accuracy=0.00934]
# Epoch 0:   8%|▊         | 85/1000 [17:48<3:11:44,  0.08it/s, v_num=4, train/loss=16.20, train/top_5_accuracy=0.0106]
# Epoch 0:   9%|▊         | 86/1000 [18:00<3:11:23,  0.08it/s, v_num=4, train/loss=16.20, train/top_5_accuracy=0.0106]
# Epoch 0:   9%|▊         | 86/1000 [18:00<3:11:27,  0.08it/s, v_num=4, train/loss=16.50, train/top_5_accuracy=0.00916]
# Epoch 0:   9%|▊         | 87/1000 [18:13<3:11:15,  0.08it/s, v_num=4, train/loss=16.50, train/top_5_accuracy=0.00916]
# Epoch 0:   9%|▊         | 87/1000 [18:13<3:11:20,  0.08it/s, v_num=4, train/loss=16.20, train/top_5_accuracy=0.0107]
# Epoch 0:   9%|▉         | 88/1000 [18:26<3:11:08,  0.08it/s, v_num=4, train/loss=16.20, train/top_5_accuracy=0.0107]
# Epoch 0:   9%|▉         | 88/1000 [18:26<3:11:12,  0.08it/s, v_num=4, train/loss=16.20, train/top_5_accuracy=0.0103]
# Epoch 0:   9%|▉         | 89/1000 [18:38<3:10:45,  0.08it/s, v_num=4, train/loss=16.20, train/top_5_accuracy=0.0103]
# Epoch 0:   9%|▉         | 89/1000 [18:38<3:10:50,  0.08it/s, v_num=4, train/loss=16.00, train/top_5_accuracy=0.0112]
# Epoch 0:   9%|▉         | 90/1000 [18:50<3:10:26,  0.08it/s, v_num=4, train/loss=16.00, train/top_5_accuracy=0.0112]
# Epoch 0:   9%|▉         | 90/1000 [18:50<3:10:29,  0.08it/s, v_num=4, train/loss=16.10, train/top_5_accuracy=0.0101]
# Epoch 0:   9%|▉         | 91/1000 [19:02<3:10:11,  0.08it/s, v_num=4, train/loss=16.10, train/top_5_accuracy=0.0101]
# Epoch 0:   9%|▉         | 91/1000 [19:02<3:10:15,  0.08it/s, v_num=4, train/loss=16.00, train/top_5_accuracy=0.0107]
# Epoch 0:   9%|▉         | 92/1000 [19:13<3:09:47,  0.08it/s, v_num=4, train/loss=16.00, train/top_5_accuracy=0.0107]
# Epoch 0:   9%|▉         | 92/1000 [19:14<3:09:51,  0.08it/s, v_num=4, train/loss=15.90, train/top_5_accuracy=0.0112]
# Epoch 0:   9%|▉         | 93/1000 [19:27<3:09:42,  0.08it/s, v_num=4, train/loss=15.90, train/top_5_accuracy=0.0112]
# Epoch 0:   9%|▉         | 93/1000 [19:27<3:09:46,  0.08it/s, v_num=4, train/loss=16.00, train/top_5_accuracy=0.0106]
# Epoch 0:   9%|▉         | 94/1000 [19:39<3:09:29,  0.08it/s, v_num=4, train/loss=16.00, train/top_5_accuracy=0.0106]
# Epoch 0:   9%|▉         | 94/1000 [19:39<3:09:33,  0.08it/s, v_num=4, train/loss=15.90, train/top_5_accuracy=0.0115]
# Epoch 0:  10%|▉         | 95/1000 [19:51<3:09:13,  0.08it/s, v_num=4, train/loss=15.90, train/top_5_accuracy=0.0115]
# Epoch 0:  10%|▉         | 95/1000 [19:52<3:09:17,  0.08it/s, v_num=4, train/loss=15.90, train/top_5_accuracy=0.0109]
# Epoch 0:  10%|▉         | 96/1000 [20:03<3:08:53,  0.08it/s, v_num=4, train/loss=15.90, train/top_5_accuracy=0.0109]
# Epoch 0:  10%|▉         | 96/1000 [20:03<3:08:57,  0.08it/s, v_num=4, train/loss=15.80, train/top_5_accuracy=0.0115]
# Epoch 0:  10%|▉         | 97/1000 [20:16<3:08:47,  0.08it/s, v_num=4, train/loss=15.80, train/top_5_accuracy=0.0115]
# Epoch 0:  10%|▉         | 97/1000 [20:17<3:08:50,  0.08it/s, v_num=4, train/loss=15.70, train/top_5_accuracy=0.0129]
# Epoch 0:  10%|▉         | 98/1000 [20:29<3:08:32,  0.08it/s, v_num=4, train/loss=15.70, train/top_5_accuracy=0.0129]
# Epoch 0:  10%|▉         | 98/1000 [20:29<3:08:36,  0.08it/s, v_num=4, train/loss=15.80, train/top_5_accuracy=0.012]
# Epoch 0:  10%|▉         | 99/1000 [20:41<3:08:19,  0.08it/s, v_num=4, train/loss=15.80, train/top_5_accuracy=0.012]
# Epoch 0:  10%|▉         | 99/1000 [20:41<3:08:22,  0.08it/s, v_num=4, train/loss=15.50, train/top_5_accuracy=0.0134]
# Epoch 0:  10%|█         | 100/1000 [20:53<3:07:57,  0.08it/s, v_num=4, train/loss=15.50, train/top_5_accuracy=0.0134]
# Epoch 0:  10%|█         | 100/1000 [20:53<3:08:01,  0.08it/s, v_num=4, train/loss=15.30, train/top_5_accuracy=0.0145]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/10 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  10%|█         | 1/10 [00:01<00:12,  0.70it/s]
#
# Validation DataLoader 0:  20%|██        | 2/10 [00:02<00:11,  0.72it/s]
#
# Validation DataLoader 0:  30%|███       | 3/10 [00:04<00:09,  0.73it/s]
#
# Validation DataLoader 0:  40%|████      | 4/10 [00:05<00:08,  0.74it/s]
#
# Validation DataLoader 0:  50%|█████     | 5/10 [00:06<00:06,  0.73it/s]
#
# Validation DataLoader 0:  60%|██████    | 6/10 [00:08<00:05,  0.73it/s]
#
# Validation DataLoader 0:  70%|███████   | 7/10 [00:09<00:04,  0.72it/s]
#
# Validation DataLoader 0:  80%|████████  | 8/10 [00:10<00:02,  0.73it/s]
#
# Validation DataLoader 0:  90%|█████████ | 9/10 [00:12<00:01,  0.73it/s]
#
# Validation DataLoader 0: 100%|██████████| 10/10 [00:13<00:00,  0.73it/s]
#
#
# Epoch 0:  10%|█         | 100/1000 [21:11<3:10:42,  0.08it/s, v_num=4, train/loss=15.30, train/top_5_accuracy=0.0145, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  10%|█         | 101/1000 [21:23<3:10:23,  0.08it/s, v_num=4, train/loss=15.30, train/top_5_accuracy=0.0145, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  10%|█         | 101/1000 [21:23<3:10:27,  0.08it/s, v_num=4, train/loss=15.40, train/top_5_accuracy=0.0146, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  10%|█         | 102/1000 [21:35<3:10:01,  0.08it/s, v_num=4, train/loss=15.40, train/top_5_accuracy=0.0146, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  10%|█         | 102/1000 [21:35<3:10:05,  0.08it/s, v_num=4, train/loss=15.30, train/top_5_accuracy=0.0142, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  10%|█         | 103/1000 [21:47<3:09:48,  0.08it/s, v_num=4, train/loss=15.30, train/top_5_accuracy=0.0142, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  10%|█         | 103/1000 [21:48<3:09:51,  0.08it/s, v_num=4, train/loss=15.60, train/top_5_accuracy=0.00989, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  10%|█         | 104/1000 [21:59<3:09:31,  0.08it/s, v_num=4, train/loss=15.60, train/top_5_accuracy=0.00989, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  10%|█         | 104/1000 [22:00<3:09:35,  0.08it/s, v_num=4, train/loss=15.50, train/top_5_accuracy=0.0114, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  10%|█         | 105/1000 [22:13<3:09:23,  0.08it/s, v_num=4, train/loss=15.50, train/top_5_accuracy=0.0114, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  10%|█         | 105/1000 [22:13<3:09:26,  0.08it/s, v_num=4, train/loss=15.40, train/top_5_accuracy=0.0128, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  11%|█         | 106/1000 [22:25<3:09:08,  0.08it/s, v_num=4, train/loss=15.40, train/top_5_accuracy=0.0128, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  11%|█         | 106/1000 [22:25<3:09:11,  0.08it/s, v_num=4, train/loss=15.20, train/top_5_accuracy=0.0135, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  11%|█         | 107/1000 [22:38<3:08:57,  0.08it/s, v_num=4, train/loss=15.20, train/top_5_accuracy=0.0135, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  11%|█         | 107/1000 [22:38<3:09:01,  0.08it/s, v_num=4, train/loss=15.10, train/top_5_accuracy=0.0142, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  11%|█         | 108/1000 [22:51<3:08:49,  0.08it/s, v_num=4, train/loss=15.10, train/top_5_accuracy=0.0142, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  11%|█         | 108/1000 [22:52<3:08:52,  0.08it/s, v_num=4, train/loss=15.10, train/top_5_accuracy=0.0151, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  11%|█         | 109/1000 [23:04<3:08:39,  0.08it/s, v_num=4, train/loss=15.10, train/top_5_accuracy=0.0151, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  11%|█         | 109/1000 [23:05<3:08:42,  0.08it/s, v_num=4, train/loss=15.00, train/top_5_accuracy=0.0151, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  11%|█         | 110/1000 [23:17<3:08:29,  0.08it/s, v_num=4, train/loss=15.00, train/top_5_accuracy=0.0151, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  11%|█         | 110/1000 [23:18<3:08:32,  0.08it/s, v_num=4, train/loss=14.90, train/top_5_accuracy=0.015, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  11%|█         | 111/1000 [23:30<3:08:14,  0.08it/s, v_num=4, train/loss=14.90, train/top_5_accuracy=0.015, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  11%|█         | 111/1000 [23:30<3:08:17,  0.08it/s, v_num=4, train/loss=15.10, train/top_5_accuracy=0.0132, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  11%|█         | 112/1000 [23:41<3:07:53,  0.08it/s, v_num=4, train/loss=15.10, train/top_5_accuracy=0.0132, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  11%|█         | 112/1000 [23:42<3:07:56,  0.08it/s, v_num=4, train/loss=15.20, train/top_5_accuracy=0.0132, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  11%|█▏        | 113/1000 [23:54<3:07:43,  0.08it/s, v_num=4, train/loss=15.20, train/top_5_accuracy=0.0132, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  11%|█▏        | 113/1000 [23:55<3:07:46,  0.08it/s, v_num=4, train/loss=15.10, train/top_5_accuracy=0.0138, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  11%|█▏        | 114/1000 [24:06<3:07:23,  0.08it/s, v_num=4, train/loss=15.10, train/top_5_accuracy=0.0138, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  11%|█▏        | 114/1000 [24:07<3:07:26,  0.08it/s, v_num=4, train/loss=15.00, train/top_5_accuracy=0.0154, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  12%|█▏        | 115/1000 [24:19<3:07:15,  0.08it/s, v_num=4, train/loss=15.00, train/top_5_accuracy=0.0154, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  12%|█▏        | 115/1000 [24:20<3:07:18,  0.08it/s, v_num=4, train/loss=15.10, train/top_5_accuracy=0.0152, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  12%|█▏        | 116/1000 [24:32<3:06:59,  0.08it/s, v_num=4, train/loss=15.10, train/top_5_accuracy=0.0152, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  12%|█▏        | 116/1000 [24:32<3:07:02,  0.08it/s, v_num=4, train/loss=14.90, train/top_5_accuracy=0.0151, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  12%|█▏        | 117/1000 [24:44<3:06:44,  0.08it/s, v_num=4, train/loss=14.90, train/top_5_accuracy=0.0151, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  12%|█▏        | 117/1000 [24:45<3:06:47,  0.08it/s, v_num=4, train/loss=15.10, train/top_5_accuracy=0.0131, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  12%|█▏        | 118/1000 [24:57<3:06:35,  0.08it/s, v_num=4, train/loss=15.10, train/top_5_accuracy=0.0131, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  12%|█▏        | 118/1000 [24:58<3:06:39,  0.08it/s, v_num=4, train/loss=14.90, train/top_5_accuracy=0.0155, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  12%|█▏        | 119/1000 [25:10<3:06:20,  0.08it/s, v_num=4, train/loss=14.90, train/top_5_accuracy=0.0155, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  12%|█▏        | 119/1000 [25:10<3:06:23,  0.08it/s, v_num=4, train/loss=14.90, train/top_5_accuracy=0.0153, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  12%|█▏        | 120/1000 [25:23<3:06:12,  0.08it/s, v_num=4, train/loss=14.90, train/top_5_accuracy=0.0153, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  12%|█▏        | 120/1000 [25:23<3:06:15,  0.08it/s, v_num=4, train/loss=15.00, train/top_5_accuracy=0.0141, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  12%|█▏        | 121/1000 [25:35<3:05:52,  0.08it/s, v_num=4, train/loss=15.00, train/top_5_accuracy=0.0141, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  12%|█▏        | 121/1000 [25:35<3:05:54,  0.08it/s, v_num=4, train/loss=14.90, train/top_5_accuracy=0.0156, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  12%|█▏        | 122/1000 [25:46<3:05:31,  0.08it/s, v_num=4, train/loss=14.90, train/top_5_accuracy=0.0156, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  12%|█▏        | 122/1000 [25:47<3:05:34,  0.08it/s, v_num=4, train/loss=14.80, train/top_5_accuracy=0.0161, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  12%|█▏        | 123/1000 [25:59<3:05:22,  0.08it/s, v_num=4, train/loss=14.80, train/top_5_accuracy=0.0161, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  12%|█▏        | 123/1000 [26:00<3:05:24,  0.08it/s, v_num=4, train/loss=14.90, train/top_5_accuracy=0.0137, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  12%|█▏        | 124/1000 [26:12<3:05:07,  0.08it/s, v_num=4, train/loss=14.90, train/top_5_accuracy=0.0137, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  12%|█▏        | 124/1000 [26:12<3:05:10,  0.08it/s, v_num=4, train/loss=14.90, train/top_5_accuracy=0.0139, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  12%|█▎        | 125/1000 [26:23<3:04:47,  0.08it/s, v_num=4, train/loss=14.90, train/top_5_accuracy=0.0139, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  12%|█▎        | 125/1000 [26:24<3:04:50,  0.08it/s, v_num=4, train/loss=14.80, train/top_5_accuracy=0.015, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  13%|█▎        | 126/1000 [26:36<3:04:33,  0.08it/s, v_num=4, train/loss=14.80, train/top_5_accuracy=0.015, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  13%|█▎        | 126/1000 [26:36<3:04:36,  0.08it/s, v_num=4, train/loss=15.00, train/top_5_accuracy=0.0139, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  13%|█▎        | 127/1000 [26:48<3:04:18,  0.08it/s, v_num=4, train/loss=15.00, train/top_5_accuracy=0.0139, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  13%|█▎        | 127/1000 [26:49<3:04:21,  0.08it/s, v_num=4, train/loss=14.90, train/top_5_accuracy=0.0137, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  13%|█▎        | 128/1000 [27:00<3:03:58,  0.08it/s, v_num=4, train/loss=14.90, train/top_5_accuracy=0.0137, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  13%|█▎        | 128/1000 [27:00<3:04:01,  0.08it/s, v_num=4, train/loss=14.80, train/top_5_accuracy=0.0153, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  13%|█▎        | 129/1000 [27:12<3:03:43,  0.08it/s, v_num=4, train/loss=14.80, train/top_5_accuracy=0.0153, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  13%|█▎        | 129/1000 [27:13<3:03:46,  0.08it/s, v_num=4, train/loss=14.80, train/top_5_accuracy=0.0164, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  13%|█▎        | 130/1000 [27:24<3:03:24,  0.08it/s, v_num=4, train/loss=14.80, train/top_5_accuracy=0.0164, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  13%|█▎        | 130/1000 [27:24<3:03:27,  0.08it/s, v_num=4, train/loss=14.60, train/top_5_accuracy=0.0167, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  13%|█▎        | 131/1000 [27:36<3:03:09,  0.08it/s, v_num=4, train/loss=14.60, train/top_5_accuracy=0.0167, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  13%|█▎        | 131/1000 [27:37<3:03:11,  0.08it/s, v_num=4, train/loss=14.80, train/top_5_accuracy=0.0157, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  13%|█▎        | 132/1000 [27:48<3:02:49,  0.08it/s, v_num=4, train/loss=14.80, train/top_5_accuracy=0.0157, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  13%|█▎        | 132/1000 [27:48<3:02:52,  0.08it/s, v_num=4, train/loss=14.80, train/top_5_accuracy=0.0143, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  13%|█▎        | 133/1000 [28:00<3:02:34,  0.08it/s, v_num=4, train/loss=14.80, train/top_5_accuracy=0.0143, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  13%|█▎        | 133/1000 [28:00<3:02:36,  0.08it/s, v_num=4, train/loss=14.60, train/top_5_accuracy=0.0157, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  13%|█▎        | 134/1000 [28:12<3:02:19,  0.08it/s, v_num=4, train/loss=14.60, train/top_5_accuracy=0.0157, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  13%|█▎        | 134/1000 [28:13<3:02:22,  0.08it/s, v_num=4, train/loss=14.80, train/top_5_accuracy=0.0139, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  14%|█▎        | 135/1000 [28:24<3:02:04,  0.08it/s, v_num=4, train/loss=14.80, train/top_5_accuracy=0.0139, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  14%|█▎        | 135/1000 [28:25<3:02:06,  0.08it/s, v_num=4, train/loss=14.90, train/top_5_accuracy=0.0132, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  14%|█▎        | 136/1000 [28:37<3:01:50,  0.08it/s, v_num=4, train/loss=14.90, train/top_5_accuracy=0.0132, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  14%|█▎        | 136/1000 [28:37<3:01:52,  0.08it/s, v_num=4, train/loss=14.60, train/top_5_accuracy=0.0156, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  14%|█▎        | 137/1000 [28:49<3:01:34,  0.08it/s, v_num=4, train/loss=14.60, train/top_5_accuracy=0.0156, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  14%|█▎        | 137/1000 [28:49<3:01:36,  0.08it/s, v_num=4, train/loss=14.80, train/top_5_accuracy=0.0146, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  14%|█▍        | 138/1000 [29:01<3:01:18,  0.08it/s, v_num=4, train/loss=14.80, train/top_5_accuracy=0.0146, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  14%|█▍        | 138/1000 [29:01<3:01:20,  0.08it/s, v_num=4, train/loss=14.70, train/top_5_accuracy=0.0143, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  14%|█▍        | 139/1000 [29:13<3:01:03,  0.08it/s, v_num=4, train/loss=14.70, train/top_5_accuracy=0.0143, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  14%|█▍        | 139/1000 [29:14<3:01:05,  0.08it/s, v_num=4, train/loss=14.70, train/top_5_accuracy=0.0161, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  14%|█▍        | 140/1000 [29:26<3:00:49,  0.08it/s, v_num=4, train/loss=14.70, train/top_5_accuracy=0.0161, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  14%|█▍        | 140/1000 [29:26<3:00:51,  0.08it/s, v_num=4, train/loss=14.60, train/top_5_accuracy=0.017, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  14%|█▍        | 141/1000 [29:38<3:00:37,  0.08it/s, v_num=4, train/loss=14.60, train/top_5_accuracy=0.017, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  14%|█▍        | 141/1000 [29:39<3:00:39,  0.08it/s, v_num=4, train/loss=14.80, train/top_5_accuracy=0.0142, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  14%|█▍        | 142/1000 [29:51<3:00:23,  0.08it/s, v_num=4, train/loss=14.80, train/top_5_accuracy=0.0142, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  14%|█▍        | 142/1000 [29:51<3:00:25,  0.08it/s, v_num=4, train/loss=14.80, train/top_5_accuracy=0.0156, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  14%|█▍        | 143/1000 [30:02<3:00:04,  0.08it/s, v_num=4, train/loss=14.80, train/top_5_accuracy=0.0156, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  14%|█▍        | 143/1000 [30:03<3:00:07,  0.08it/s, v_num=4, train/loss=14.60, train/top_5_accuracy=0.0155, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  14%|█▍        | 144/1000 [30:14<2:59:46,  0.08it/s, v_num=4, train/loss=14.60, train/top_5_accuracy=0.0155, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  14%|█▍        | 144/1000 [30:14<2:59:48,  0.08it/s, v_num=4, train/loss=14.60, train/top_5_accuracy=0.0157, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  14%|█▍        | 145/1000 [30:27<2:59:36,  0.08it/s, v_num=4, train/loss=14.60, train/top_5_accuracy=0.0157, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  14%|█▍        | 145/1000 [30:28<2:59:39,  0.08it/s, v_num=4, train/loss=14.80, train/top_5_accuracy=0.0139, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  15%|█▍        | 146/1000 [30:39<2:59:21,  0.08it/s, v_num=4, train/loss=14.80, train/top_5_accuracy=0.0139, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  15%|█▍        | 146/1000 [30:40<2:59:24,  0.08it/s, v_num=4, train/loss=14.60, train/top_5_accuracy=0.0151, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  15%|█▍        | 147/1000 [30:52<2:59:12,  0.08it/s, v_num=4, train/loss=14.60, train/top_5_accuracy=0.0151, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  15%|█▍        | 147/1000 [30:53<2:59:14,  0.08it/s, v_num=4, train/loss=14.80, train/top_5_accuracy=0.0135, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  15%|█▍        | 148/1000 [31:06<2:59:02,  0.08it/s, v_num=4, train/loss=14.80, train/top_5_accuracy=0.0135, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  15%|█▍        | 148/1000 [31:06<2:59:04,  0.08it/s, v_num=4, train/loss=14.80, train/top_5_accuracy=0.0155, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  15%|█▍        | 149/1000 [31:18<2:58:49,  0.08it/s, v_num=4, train/loss=14.80, train/top_5_accuracy=0.0155, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  15%|█▍        | 149/1000 [31:19<2:58:52,  0.08it/s, v_num=4, train/loss=14.60, train/top_5_accuracy=0.0148, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  15%|█▌        | 150/1000 [31:31<2:58:39,  0.08it/s, v_num=4, train/loss=14.60, train/top_5_accuracy=0.0148, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  15%|█▌        | 150/1000 [31:32<2:58:41,  0.08it/s, v_num=4, train/loss=14.80, train/top_5_accuracy=0.0145, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  15%|█▌        | 151/1000 [31:44<2:58:25,  0.08it/s, v_num=4, train/loss=14.80, train/top_5_accuracy=0.0145, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  15%|█▌        | 151/1000 [31:44<2:58:28,  0.08it/s, v_num=4, train/loss=14.60, train/top_5_accuracy=0.0154, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  15%|█▌        | 152/1000 [31:56<2:58:14,  0.08it/s, v_num=4, train/loss=14.60, train/top_5_accuracy=0.0154, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  15%|█▌        | 152/1000 [31:57<2:58:16,  0.08it/s, v_num=4, train/loss=14.50, train/top_5_accuracy=0.0149, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  15%|█▌        | 153/1000 [32:09<2:58:00,  0.08it/s, v_num=4, train/loss=14.50, train/top_5_accuracy=0.0149, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  15%|█▌        | 153/1000 [32:09<2:58:02,  0.08it/s, v_num=4, train/loss=14.60, train/top_5_accuracy=0.0176, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  15%|█▌        | 154/1000 [32:20<2:57:42,  0.08it/s, v_num=4, train/loss=14.60, train/top_5_accuracy=0.0176, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  15%|█▌        | 154/1000 [32:21<2:57:44,  0.08it/s, v_num=4, train/loss=14.90, train/top_5_accuracy=0.0147, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  16%|█▌        | 155/1000 [32:32<2:57:23,  0.08it/s, v_num=4, train/loss=14.90, train/top_5_accuracy=0.0147, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  16%|█▌        | 155/1000 [32:32<2:57:25,  0.08it/s, v_num=4, train/loss=14.50, train/top_5_accuracy=0.0168, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  16%|█▌        | 156/1000 [32:45<2:57:13,  0.08it/s, v_num=4, train/loss=14.50, train/top_5_accuracy=0.0168, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  16%|█▌        | 156/1000 [32:45<2:57:15,  0.08it/s, v_num=4, train/loss=14.60, train/top_5_accuracy=0.0154, val/loss=15.50, val/top_5_accuracy=0.0129]
# Epoch 0:  16%|█▌        | 157/1000 [32:57<2:56:58,  0.08it/s, v_num=4, train/loss=14.60, train/top_5_accuracy=0.0154, val/loss=15.50, val/top_5_accuracy=0.0129]
# ...
# Epoch 0:  96%|█████████▌| 956/1000 [3:21:26<09:16,  0.08it/s, v_num=4, train/loss=14.40, train/top_5_accuracy=0.0201, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  96%|█████████▌| 957/1000 [3:21:38<09:03,  0.08it/s, v_num=4, train/loss=14.40, train/top_5_accuracy=0.0201, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  96%|█████████▌| 957/1000 [3:21:38<09:03,  0.08it/s, v_num=4, train/loss=14.20, train/top_5_accuracy=0.0228, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  96%|█████████▌| 958/1000 [3:21:50<08:50,  0.08it/s, v_num=4, train/loss=14.20, train/top_5_accuracy=0.0228, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  96%|█████████▌| 958/1000 [3:21:51<08:50,  0.08it/s, v_num=4, train/loss=14.40, train/top_5_accuracy=0.0212, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  96%|█████████▌| 959/1000 [3:22:03<08:38,  0.08it/s, v_num=4, train/loss=14.40, train/top_5_accuracy=0.0212, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  96%|█████████▌| 959/1000 [3:22:04<08:38,  0.08it/s, v_num=4, train/loss=14.50, train/top_5_accuracy=0.0171, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  96%|█████████▌| 960/1000 [3:22:17<08:25,  0.08it/s, v_num=4, train/loss=14.50, train/top_5_accuracy=0.0171, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  96%|█████████▌| 960/1000 [3:22:17<08:25,  0.08it/s, v_num=4, train/loss=14.40, train/top_5_accuracy=0.0222, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  96%|█████████▌| 961/1000 [3:22:28<08:13,  0.08it/s, v_num=4, train/loss=14.40, train/top_5_accuracy=0.0222, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  96%|█████████▌| 961/1000 [3:22:29<08:13,  0.08it/s, v_num=4, train/loss=14.20, train/top_5_accuracy=0.0236, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  96%|█████████▌| 962/1000 [3:22:42<08:00,  0.08it/s, v_num=4, train/loss=14.20, train/top_5_accuracy=0.0236, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  96%|█████████▌| 962/1000 [3:22:42<08:00,  0.08it/s, v_num=4, train/loss=14.30, train/top_5_accuracy=0.0236, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  96%|█████████▋| 963/1000 [3:22:54<07:47,  0.08it/s, v_num=4, train/loss=14.30, train/top_5_accuracy=0.0236, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  96%|█████████▋| 963/1000 [3:22:54<07:47,  0.08it/s, v_num=4, train/loss=14.20, train/top_5_accuracy=0.0238, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  96%|█████████▋| 964/1000 [3:23:06<07:35,  0.08it/s, v_num=4, train/loss=14.20, train/top_5_accuracy=0.0238, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  96%|█████████▋| 964/1000 [3:23:07<07:35,  0.08it/s, v_num=4, train/loss=14.50, train/top_5_accuracy=0.0193, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  96%|█████████▋| 965/1000 [3:23:19<07:22,  0.08it/s, v_num=4, train/loss=14.50, train/top_5_accuracy=0.0193, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  96%|█████████▋| 965/1000 [3:23:19<07:22,  0.08it/s, v_num=4, train/loss=14.20, train/top_5_accuracy=0.0227, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  97%|█████████▋| 966/1000 [3:23:31<07:09,  0.08it/s, v_num=4, train/loss=14.20, train/top_5_accuracy=0.0227, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  97%|█████████▋| 966/1000 [3:23:31<07:09,  0.08it/s, v_num=4, train/loss=14.40, train/top_5_accuracy=0.0206, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  97%|█████████▋| 967/1000 [3:23:43<06:57,  0.08it/s, v_num=4, train/loss=14.40, train/top_5_accuracy=0.0206, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  97%|█████████▋| 967/1000 [3:23:44<06:57,  0.08it/s, v_num=4, train/loss=14.40, train/top_5_accuracy=0.0209, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  97%|█████████▋| 968/1000 [3:23:55<06:44,  0.08it/s, v_num=4, train/loss=14.40, train/top_5_accuracy=0.0209, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  97%|█████████▋| 968/1000 [3:23:56<06:44,  0.08it/s, v_num=4, train/loss=14.30, train/top_5_accuracy=0.0211, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  97%|█████████▋| 969/1000 [3:24:07<06:31,  0.08it/s, v_num=4, train/loss=14.30, train/top_5_accuracy=0.0211, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  97%|█████████▋| 969/1000 [3:24:07<06:31,  0.08it/s, v_num=4, train/loss=14.20, train/top_5_accuracy=0.0231, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  97%|█████████▋| 970/1000 [3:24:19<06:19,  0.08it/s, v_num=4, train/loss=14.20, train/top_5_accuracy=0.0231, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  97%|█████████▋| 970/1000 [3:24:20<06:19,  0.08it/s, v_num=4, train/loss=14.40, train/top_5_accuracy=0.0216, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  97%|█████████▋| 971/1000 [3:24:32<06:06,  0.08it/s, v_num=4, train/loss=14.40, train/top_5_accuracy=0.0216, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  97%|█████████▋| 971/1000 [3:24:32<06:06,  0.08it/s, v_num=4, train/loss=14.40, train/top_5_accuracy=0.0192, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  97%|█████████▋| 972/1000 [3:24:44<05:53,  0.08it/s, v_num=4, train/loss=14.40, train/top_5_accuracy=0.0192, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  97%|█████████▋| 972/1000 [3:24:44<05:53,  0.08it/s, v_num=4, train/loss=14.40, train/top_5_accuracy=0.0216, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  97%|█████████▋| 973/1000 [3:24:56<05:41,  0.08it/s, v_num=4, train/loss=14.40, train/top_5_accuracy=0.0216, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  97%|█████████▋| 973/1000 [3:24:57<05:41,  0.08it/s, v_num=4, train/loss=14.40, train/top_5_accuracy=0.0209, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  97%|█████████▋| 974/1000 [3:25:08<05:28,  0.08it/s, v_num=4, train/loss=14.40, train/top_5_accuracy=0.0209, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  97%|█████████▋| 974/1000 [3:25:08<05:28,  0.08it/s, v_num=4, train/loss=14.20, train/top_5_accuracy=0.0243, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  98%|█████████▊| 975/1000 [3:25:20<05:15,  0.08it/s, v_num=4, train/loss=14.20, train/top_5_accuracy=0.0243, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  98%|█████████▊| 975/1000 [3:25:21<05:15,  0.08it/s, v_num=4, train/loss=14.40, train/top_5_accuracy=0.0209, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  98%|█████████▊| 976/1000 [3:25:33<05:03,  0.08it/s, v_num=4, train/loss=14.40, train/top_5_accuracy=0.0209, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  98%|█████████▊| 976/1000 [3:25:33<05:03,  0.08it/s, v_num=4, train/loss=14.40, train/top_5_accuracy=0.0236, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  98%|█████████▊| 977/1000 [3:25:45<04:50,  0.08it/s, v_num=4, train/loss=14.40, train/top_5_accuracy=0.0236, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  98%|█████████▊| 977/1000 [3:25:45<04:50,  0.08it/s, v_num=4, train/loss=14.40, train/top_5_accuracy=0.0228, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  98%|█████████▊| 978/1000 [3:25:57<04:37,  0.08it/s, v_num=4, train/loss=14.40, train/top_5_accuracy=0.0228, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  98%|█████████▊| 978/1000 [3:25:57<04:37,  0.08it/s, v_num=4, train/loss=14.20, train/top_5_accuracy=0.0225, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  98%|█████████▊| 979/1000 [3:26:09<04:25,  0.08it/s, v_num=4, train/loss=14.20, train/top_5_accuracy=0.0225, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  98%|█████████▊| 979/1000 [3:26:10<04:25,  0.08it/s, v_num=4, train/loss=14.40, train/top_5_accuracy=0.0212, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  98%|█████████▊| 980/1000 [3:26:21<04:12,  0.08it/s, v_num=4, train/loss=14.40, train/top_5_accuracy=0.0212, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  98%|█████████▊| 980/1000 [3:26:22<04:12,  0.08it/s, v_num=4, train/loss=14.40, train/top_5_accuracy=0.020, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  98%|█████████▊| 981/1000 [3:26:33<04:00,  0.08it/s, v_num=4, train/loss=14.40, train/top_5_accuracy=0.020, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  98%|█████████▊| 981/1000 [3:26:33<04:00,  0.08it/s, v_num=4, train/loss=14.50, train/top_5_accuracy=0.0198, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  98%|█████████▊| 982/1000 [3:26:45<03:47,  0.08it/s, v_num=4, train/loss=14.50, train/top_5_accuracy=0.0198, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  98%|█████████▊| 982/1000 [3:26:46<03:47,  0.08it/s, v_num=4, train/loss=14.20, train/top_5_accuracy=0.024, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  98%|█████████▊| 983/1000 [3:26:57<03:34,  0.08it/s, v_num=4, train/loss=14.20, train/top_5_accuracy=0.024, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  98%|█████████▊| 983/1000 [3:26:58<03:34,  0.08it/s, v_num=4, train/loss=14.20, train/top_5_accuracy=0.0239, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  98%|█████████▊| 984/1000 [3:27:11<03:22,  0.08it/s, v_num=4, train/loss=14.20, train/top_5_accuracy=0.0239, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  98%|█████████▊| 984/1000 [3:27:11<03:22,  0.08it/s, v_num=4, train/loss=14.20, train/top_5_accuracy=0.0231, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  98%|█████████▊| 985/1000 [3:27:22<03:09,  0.08it/s, v_num=4, train/loss=14.20, train/top_5_accuracy=0.0231, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  98%|█████████▊| 985/1000 [3:27:23<03:09,  0.08it/s, v_num=4, train/loss=14.20, train/top_5_accuracy=0.0242, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  99%|█████████▊| 986/1000 [3:27:35<02:56,  0.08it/s, v_num=4, train/loss=14.20, train/top_5_accuracy=0.0242, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  99%|█████████▊| 986/1000 [3:27:35<02:56,  0.08it/s, v_num=4, train/loss=14.50, train/top_5_accuracy=0.0173, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  99%|█████████▊| 987/1000 [3:27:46<02:44,  0.08it/s, v_num=4, train/loss=14.50, train/top_5_accuracy=0.0173, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  99%|█████████▊| 987/1000 [3:27:46<02:44,  0.08it/s, v_num=4, train/loss=14.30, train/top_5_accuracy=0.0228, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  99%|█████████▉| 988/1000 [3:27:57<02:31,  0.08it/s, v_num=4, train/loss=14.30, train/top_5_accuracy=0.0228, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  99%|█████████▉| 988/1000 [3:27:58<02:31,  0.08it/s, v_num=4, train/loss=14.30, train/top_5_accuracy=0.0221, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  99%|█████████▉| 989/1000 [3:28:09<02:18,  0.08it/s, v_num=4, train/loss=14.30, train/top_5_accuracy=0.0221, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  99%|█████████▉| 989/1000 [3:28:10<02:18,  0.08it/s, v_num=4, train/loss=14.40, train/top_5_accuracy=0.0187, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  99%|█████████▉| 990/1000 [3:28:22<02:06,  0.08it/s, v_num=4, train/loss=14.40, train/top_5_accuracy=0.0187, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  99%|█████████▉| 990/1000 [3:28:22<02:06,  0.08it/s, v_num=4, train/loss=14.30, train/top_5_accuracy=0.0229, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  99%|█████████▉| 991/1000 [3:28:35<01:53,  0.08it/s, v_num=4, train/loss=14.30, train/top_5_accuracy=0.0229, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  99%|█████████▉| 991/1000 [3:28:35<01:53,  0.08it/s, v_num=4, train/loss=14.50, train/top_5_accuracy=0.0188, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  99%|█████████▉| 992/1000 [3:28:47<01:41,  0.08it/s, v_num=4, train/loss=14.50, train/top_5_accuracy=0.0188, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  99%|█████████▉| 992/1000 [3:28:47<01:41,  0.08it/s, v_num=4, train/loss=14.30, train/top_5_accuracy=0.0212, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  99%|█████████▉| 993/1000 [3:28:58<01:28,  0.08it/s, v_num=4, train/loss=14.30, train/top_5_accuracy=0.0212, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  99%|█████████▉| 993/1000 [3:28:59<01:28,  0.08it/s, v_num=4, train/loss=14.40, train/top_5_accuracy=0.0201, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  99%|█████████▉| 994/1000 [3:29:10<01:15,  0.08it/s, v_num=4, train/loss=14.40, train/top_5_accuracy=0.0201, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0:  99%|█████████▉| 994/1000 [3:29:10<01:15,  0.08it/s, v_num=4, train/loss=14.20, train/top_5_accuracy=0.0229, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0: 100%|█████████▉| 995/1000 [3:29:21<01:03,  0.08it/s, v_num=4, train/loss=14.20, train/top_5_accuracy=0.0229, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0: 100%|█████████▉| 995/1000 [3:29:22<01:03,  0.08it/s, v_num=4, train/loss=14.20, train/top_5_accuracy=0.0242, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0: 100%|█████████▉| 996/1000 [3:29:33<00:50,  0.08it/s, v_num=4, train/loss=14.20, train/top_5_accuracy=0.0242, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0: 100%|█████████▉| 996/1000 [3:29:34<00:50,  0.08it/s, v_num=4, train/loss=14.30, train/top_5_accuracy=0.0211, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0: 100%|█████████▉| 997/1000 [3:29:46<00:37,  0.08it/s, v_num=4, train/loss=14.30, train/top_5_accuracy=0.0211, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0: 100%|█████████▉| 997/1000 [3:29:46<00:37,  0.08it/s, v_num=4, train/loss=14.20, train/top_5_accuracy=0.0222, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0: 100%|█████████▉| 998/1000 [3:29:57<00:25,  0.08it/s, v_num=4, train/loss=14.20, train/top_5_accuracy=0.0222, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0: 100%|█████████▉| 998/1000 [3:29:58<00:25,  0.08it/s, v_num=4, train/loss=14.30, train/top_5_accuracy=0.0231, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0: 100%|█████████▉| 999/1000 [3:30:09<00:12,  0.08it/s, v_num=4, train/loss=14.30, train/top_5_accuracy=0.0231, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0: 100%|█████████▉| 999/1000 [3:30:09<00:12,  0.08it/s, v_num=4, train/loss=14.20, train/top_5_accuracy=0.0219, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0: 100%|██████████| 1000/1000 [3:30:22<00:00,  0.08it/s, v_num=4, train/loss=14.20, train/top_5_accuracy=0.0219, val/loss=14.30, val/top_5_accuracy=0.0217]
# Epoch 0: 100%|██████████| 1000/1000 [3:30:22<00:00,  0.08it/s, v_num=4, train/loss=14.20, train/top_5_accuracy=0.0219, val/loss=14.30, val/top_5_accuracy=0.0217]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/10 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  10%|█         | 1/10 [00:01<00:12,  0.70it/s]
#
# Validation DataLoader 0:  20%|██        | 2/10 [00:02<00:11,  0.73it/s]
#
# Validation DataLoader 0:  30%|███       | 3/10 [00:04<00:09,  0.72it/s]
#
# Validation DataLoader 0:  40%|████      | 4/10 [00:05<00:08,  0.73it/s]
#
# Validation DataLoader 0:  50%|█████     | 5/10 [00:06<00:06,  0.72it/s]
#
# Validation DataLoader 0:  60%|██████    | 6/10 [00:08<00:05,  0.73it/s]
#
# Validation DataLoader 0:  70%|███████   | 7/10 [00:09<00:04,  0.72it/s]
#
# Validation DataLoader 0:  80%|████████  | 8/10 [00:10<00:02,  0.73it/s]
#
# Validation DataLoader 0:  90%|█████████ | 9/10 [00:12<00:01,  0.73it/s]
#
# Validation DataLoader 0: 100%|██████████| 10/10 [00:13<00:00,  0.73it/s]
#
#
# Epoch 0: 100%|██████████| 1000/1000 [3:30:40<00:00,  0.08it/s, v_num=4, train/loss=14.20, train/top_5_accuracy=0.0219, val/loss=14.30, val/top_5_accuracy=0.0215]
# Epoch 0: 100%|██████████| 1000/1000 [3:30:40<00:00,  0.08it/s, v_num=4, train/loss=14.20, train/top_5_accuracy=0.0219, val/loss=14.30, val/top_5_accuracy=0.0215]`Trainer.fit` stopped: `max_steps=1000` reached.
#
# Epoch 0: 100%|██████████| 1000/1000 [3:30:40<00:00,  0.08it/s, v_num=4, train/loss=14.20, train/top_5_accuracy=0.0219, val/loss=14.30, val/top_5_accuracy=0.0215]
# [2025-12-19 09:29:42,732][fish_speech.utils.utils][INFO] - [rank: 0] Output dir: results/neymar_finetune
#
# [OK] Training completed in 211.9 minutes

# %%
# Cell 8: Merge LoRA weights
results_dir = Path(f"results/{PROJECT_NAME}/checkpoints")

if not results_dir.exists():
    print(f"[ERROR] No results found. Run training first.")
else:
    checkpoints = sorted(results_dir.glob("*.ckpt"))
    
    if checkpoints:
        LORA_CHECKPOINT = checkpoints[-1]
        print(f"Using checkpoint: {LORA_CHECKPOINT.name}")
        
        cmd = [
            sys.executable,
            "tools/llama/merge_lora.py",
            "--lora-config", f"r_{LORA_R}_alpha_{LORA_ALPHA}",
            "--base-weight", str(CHECKPOINT_PATH),
            "--lora-weight", str(LORA_CHECKPOINT),
            "--output", str(OUTPUT_MODEL),
        ]
        
        result = subprocess.run(cmd, capture_output=True, text=True, encoding='utf-8', errors='replace')
        
        if result.returncode == 0:
            print(f"[OK] Model saved to {OUTPUT_MODEL}")
            for f in OUTPUT_MODEL.iterdir():
                print(f"  - {f.name}")
        else:
            print(f"[ERROR] Merge failed")
            print(result.stderr)
# Out:
# Using checkpoint: step_000001000.ckpt
# [OK] Model saved to checkpoints\openaudio-s1-mini-neymar
#   - config.json
#   - model.pth
#   - special_tokens.json
#   - tokenizer.tiktoken

# %%
# Cell 9: Test finetuned model
TEST_MODEL = OUTPUT_MODEL if OUTPUT_MODEL.exists() else CHECKPOINT_PATH
TEST_TEXT = "Hello, this is a test of the finetuned voice."

# Get reference from dataset
sample_wavs = list(WAVS_DIR.glob("*.wav"))[:1]
REF_AUDIO = sample_wavs[0] if sample_wavs else None

print(f"Model: {TEST_MODEL}")
print(f"Text: {TEST_TEXT}")

# Encode reference
# Note: Use base model's codec (merged model doesn't include codec.pth)
if REF_AUDIO:
    result = subprocess.run([
        sys.executable, "fish_speech/models/dac/inference.py",
        "-i", str(REF_AUDIO),
        "--checkpoint-path", str(CHECKPOINT_PATH / "codec.pth"),
    ], capture_output=True, text=True, encoding='utf-8', errors='replace')
    if result.returncode != 0:
        print(f"[WARN] Reference encoding failed: {result.stderr[-200:] if result.stderr else 'No error output'}")

# Generate semantic tokens
# Note: Don't use prompt tokens for simple TTS - they cause the model to generate
# based on the reference audio content rather than the text input
# Prompt tokens are for voice cloning, not for controlling content
cmd = [
    sys.executable, "fish_speech/models/text2semantic/inference.py",
    "--text", TEST_TEXT,
    "--checkpoint-path", str(TEST_MODEL),
]
# #region agent log
import json
log_path = project_root / ".cursor" / "debug.log"
log_path.parent.mkdir(parents=True, exist_ok=True)
with open(log_path, 'a', encoding='utf-8') as f:
    json.dump({"sessionId": "debug-session", "runId": "run4", "hypothesisId": "G", "location": "notebook:cell10", "message": "Generating semantic tokens", "data": {"text": TEST_TEXT, "model": str(TEST_MODEL), "using_prompt_tokens": False}, "timestamp": int(time.time() * 1000)}, f)
    f.write('\n')
# #endregion

result = subprocess.run(cmd, capture_output=True, text=True, encoding='utf-8', errors='replace')

# #region agent log
with open(log_path, 'a', encoding='utf-8') as f:
    json.dump({"sessionId": "debug-session", "runId": "run4", "hypothesisId": "G", "location": "notebook:cell10", "message": "Text2semantic result", "data": {"returncode": result.returncode, "stdout": result.stdout[-500:] if result.stdout else None, "stderr": result.stderr[-500:] if result.stderr else None}, "timestamp": int(time.time() * 1000)}, f)
    f.write('\n')
# #endregion

if result.returncode != 0:
    print(f"[ERROR] Text2semantic generation failed:")
    if result.stderr:
        print(result.stderr[-1000:])
    if result.stdout:
        print("STDOUT:", result.stdout[-500:])

# Decode to audio
# Note: Use base model's codec (merged model doesn't include codec.pth)
if Path("temp/codes_0.npy").exists():
    # #region agent log
    import json
    log_path = project_root / ".cursor" / "debug.log"
    log_path.parent.mkdir(parents=True, exist_ok=True)
    codec_path = CHECKPOINT_PATH / "codec.pth"
    with open(log_path, 'a', encoding='utf-8') as f:
        json.dump({"sessionId": "debug-session", "runId": "run3", "hypothesisId": "F", "location": "notebook:cell10", "message": "Decoding audio", "data": {"codes_file": "temp/codes_0.npy", "codec_path": str(codec_path), "codec_exists": codec_path.exists()}, "timestamp": int(time.time() * 1000)}, f)
        f.write('\n')
    # #endregion
    
    result = subprocess.run([
        sys.executable, "fish_speech/models/dac/inference.py",
        "-i", "temp/codes_0.npy",
        "--checkpoint-path", str(codec_path),
        "-o", "fake.wav",
    ], capture_output=True, text=True, encoding='utf-8', errors='replace')
    
    # #region agent log
    with open(log_path, 'a', encoding='utf-8') as f:
        json.dump({"sessionId": "debug-session", "runId": "run3", "hypothesisId": "F", "location": "notebook:cell10", "message": "DAC decode result", "data": {"returncode": result.returncode, "stdout": result.stdout[-500:] if result.stdout else None, "stderr": result.stderr[-500:] if result.stderr else None}, "timestamp": int(time.time() * 1000)}, f)
        f.write('\n')
    # #endregion
    
    if result.returncode != 0:
        print(f"[ERROR] DAC decode failed:")
        if result.stderr:
            print(result.stderr[-1000:])
        if result.stdout:
            print("STDOUT:", result.stdout[-500:])

# Play result
if Path("fake.wav").exists():
    final_path = Path(f"outputs/{DATASET_NAME}_test.wav")
    Path("outputs").mkdir(exist_ok=True)
    shutil.move("fake.wav", final_path)
    print(f"[OK] Saved to {final_path}")
    display(Audio(filename=str(final_path)))
else:
    print("[ERROR] Generation failed")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Cell 9: Test finetuned model
# ----> 2 TEST_MODEL = OUTPUT_MODEL if OUTPUT_MODEL.exists() else CHECKPOINT_PATH
#       3 TEST_TEXT = "Hello, this is a test of the finetuned voice."
#       5 # Get reference from dataset
#
# NameError: name 'OUTPUT_MODEL' is not defined

# %%
# Standalone Test Cell - Test Finetuned Model
# This cell can be run independently without running previous cells
# It tests the finetuned model with a short text to avoid long generation times

import os
import sys
import subprocess
import shutil
from pathlib import Path
import time

# Setup paths - use absolute paths to avoid resolution issues
# Try multiple methods to find the project root
import os

# Method 1: Try to find fish_speech starting from current directory
current = Path(os.getcwd()).resolve()
project_root = None

# Search upward from current directory
search_path = current
max_depth = 10
for _ in range(max_depth):
    if (search_path / "fish_speech").exists():
        project_root = search_path
        break
    if search_path == search_path.parent:  # Reached root
        break
    search_path = search_path.parent

# Method 2: If not found, try common locations
if project_root is None:
    # Try Desktop/fish-speech
    desktop = Path.home() / "Desktop" / "fish-speech"
    if (desktop / "fish_speech").exists():
        project_root = desktop

# Method 3: Try relative to this notebook file location (if available)
if project_root is None:
    try:
        # In Jupyter, we can try to infer from sys.path
        for path in sys.path:
            p = Path(path).resolve()
            if (p / "fish_speech").exists():
                project_root = p
                break
            # Also check parent
            if (p.parent / "fish_speech").exists():
                project_root = p.parent
                break
    except:
        pass

if project_root is None:
    raise RuntimeError(
        f"Could not find fish_speech directory.\n"
        f"Current working directory: {os.getcwd()}\n"
        f"Searched from: {current}\n"
        f"Please ensure you're running from the fish-speech repository root or set PROJECT_ROOT environment variable."
    )

project_root = project_root.resolve()
print(f"Current working directory: {os.getcwd()}")
print(f"Project root found: {project_root}")

os.chdir(project_root)
sys.path.insert(0, str(project_root))

# Configuration - adjust these as needed
FINETUNED_MODEL = project_root / "checkpoints/openaudio-s1-mini-neymar"
BASE_MODEL = project_root / "checkpoints/openaudio-s1-mini"
TEST_TEXT = "Hello, this is a test."
MAX_NEW_TOKENS = 200  # Limit generation length for faster testing
OUTPUT_DIR = (project_root / "temp").resolve()
print(f"Output directory: {OUTPUT_DIR}")

# Create output directory with proper error handling
try:
    OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
    print(f"[OK] Output directory ready: {OUTPUT_DIR}")
except (PermissionError, OSError) as e:
    # Fallback: use a temp directory in user's temp folder
    import tempfile
    OUTPUT_DIR = Path(tempfile.gettempdir()) / "fish_speech_test"
    OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
    print(f"[WARN] Could not create temp dir in project root ({e}), using: {OUTPUT_DIR}")

# Set to True to test base model first (for comparison)
TEST_BASE_MODEL_FIRST = False  # Now testing finetuned model with proper 1000-step checkpoint

print("="*60)
print("STANDALONE FINETUNED MODEL TEST")
print("="*60)
print(f"Finetuned model: {FINETUNED_MODEL}")
print(f"Base model (for codec): {BASE_MODEL}")
print(f"Test text: {TEST_TEXT}")
print(f"Max tokens: {MAX_NEW_TOKENS}")
print()

# Check if models exist
TEST_MODEL = None
OUTPUT_SUFFIX = "_finetuned"

if not BASE_MODEL.exists():
    print(f"[ERROR] Base model not found: {BASE_MODEL}")
elif TEST_BASE_MODEL_FIRST:
    print("[INFO] Testing base model first for comparison...")
    TEST_MODEL = BASE_MODEL
    OUTPUT_SUFFIX = "_base"
else:
    if not FINETUNED_MODEL.exists():
        print(f"[ERROR] Finetuned model not found: {FINETUNED_MODEL}")
        print("Please run the training and merge cells first.")
    else:
        TEST_MODEL = FINETUNED_MODEL
        OUTPUT_SUFFIX = "_finetuned"

if TEST_MODEL:
    # Step 1: Generate semantic tokens
    print("[1/3] Generating semantic tokens...")
    total_start = time.time()
    step_start = time.time()
    
    cmd = [
        sys.executable,
        "fish_speech/models/text2semantic/inference.py",
        "--text", TEST_TEXT,
        "--checkpoint-path", str(TEST_MODEL),
        "--max-new-tokens", str(MAX_NEW_TOKENS),  # Limit generation length
        "--output-dir", str(OUTPUT_DIR),
    ]
    
    result = subprocess.run(
        cmd,
        capture_output=True,
        text=True,
        encoding='utf-8',
        errors='replace'
    )
    
    elapsed = time.time() - step_start
    
    if result.returncode != 0:
        print(f"[ERROR] Text2semantic generation failed after {elapsed:.1f}s")
        if result.stderr:
            print("STDERR:", result.stderr[-500:])
        if result.stdout:
            print("STDOUT:", result.stdout[-500:])
    else:
        print(f"[OK] Semantic tokens generated in {elapsed:.1f}s")
        
        # Step 2: Decode to audio
        codes_file = OUTPUT_DIR / "codes_0.npy"
        if codes_file.exists():
            # Validate codes before decoding
            import numpy as np
            codes = np.load(codes_file)
            print(f"  Codes shape: {codes.shape}")
            print(f"  Codes dtype: {codes.dtype}")
            print(f"  Codes range: {codes.min()} - {codes.max()}")
            
            # Check for potential issues
            if codes.shape[0] != 10:
                print(f"  [WARN] Expected 10 codebooks, got {codes.shape[0]}")
            if codes.max() >= 4096:
                print(f"  [WARN] Code values exceed codebook size (max={codes.max()})")
            if (codes == 0).sum() / codes.size > 0.9:
                print(f"  [WARN] Too many zeros in codes ({(codes == 0).sum() / codes.size * 100:.1f}%)")
            
            # Check first codebook (should be semantic, can have zeros)
            non_zero_first = (codes[0] != 0).sum()
            print(f"  First codebook non-zero tokens: {non_zero_first}/{codes.shape[1]}")
            
            # Check other codebooks (should have values)
            for i in range(1, min(4, codes.shape[0])):
                non_zero = (codes[i] != 0).sum()
                print(f"  Codebook {i} non-zero tokens: {non_zero}/{codes.shape[1]}")
            
            if codes.shape[0] == 10 and codes.max() < 4096:
                print(f"[2/3] Decoding audio from {codes_file}...")
                step_start = time.time()
                
                cmd = [
                    sys.executable,
                    "fish_speech/models/dac/inference.py",
                    "-i", str(codes_file),
                    "--checkpoint-path", str(BASE_MODEL / "codec.pth"),
                    "-o", str(OUTPUT_DIR / f"test_output{OUTPUT_SUFFIX}.wav"),
                ]
                
                result = subprocess.run(
                    cmd,
                    capture_output=True,
                    text=True,
                    encoding='utf-8',
                    errors='replace'
                )
                
                elapsed = time.time() - step_start
                
                if result.returncode != 0:
                    print(f"[ERROR] Audio decoding failed after {elapsed:.1f}s")
                    if result.stderr:
                        print("STDERR:", result.stderr[-500:])
                else:
                    print(f"[OK] Audio decoded in {elapsed:.1f}s")
                    
                    # Step 3: Display result
                    output_wav = OUTPUT_DIR / f"test_output{OUTPUT_SUFFIX}.wav"
                    if output_wav.exists():
                        print(f"[3/3] Success! Audio saved to: {output_wav}")
                        print(f"Total time: {time.time() - total_start:.1f}s")
                        
                        if TEST_BASE_MODEL_FIRST:
                            print("\n[INFO] Base model test complete. Set TEST_BASE_MODEL_FIRST=False to test finetuned model.")
                        
                        # Try to display audio if IPython is available
                        try:
                            from IPython.display import Audio, display
                            display(Audio(filename=str(output_wav)))
                        except ImportError:
                            print("(Install IPython to play audio in notebook)")
                    else:
                        print("[ERROR] Output audio file not found")
            else:
                print("[ERROR] Codes validation failed - check warnings above")
                print("The finetuned model may not have converged properly.")
                print("Try:")
                print("  1. Training for more steps")
                print("  2. Using the base model to verify the pipeline works")
                print("  3. Checking training logs for convergence issues")
        else:
            print(f"[ERROR] Codes file not found: {codes_file}")
            print("Check the text2semantic generation output above for errors.")
# Out:
# Current working directory: C:\Users\PC\Desktop\fish-speech
# Project root found: C:\Users\PC\Desktop\fish-speech
# Output directory: C:\Users\PC\Desktop\fish-speech\temp
# [OK] Output directory ready: C:\Users\PC\Desktop\fish-speech\temp
# ============================================================
# STANDALONE FINETUNED MODEL TEST
# ============================================================
# Finetuned model: C:\Users\PC\Desktop\fish-speech\checkpoints\openaudio-s1-mini-neymar
# Base model (for codec): C:\Users\PC\Desktop\fish-speech\checkpoints\openaudio-s1-mini
# Test text: Hello, this is a test.
# Max tokens: 200
#
# [1/3] Generating semantic tokens...
# [OK] Semantic tokens generated in 22.4s
#   Codes shape: (10, 199)
#   Codes dtype: int32
#   Codes range: 0 - 4061
#   First codebook non-zero tokens: 6/199
#   Codebook 1 non-zero tokens: 199/199
#   Codebook 2 non-zero tokens: 198/199
#   Codebook 3 non-zero tokens: 199/199
# [2/3] Decoding audio from C:\Users\PC\Desktop\fish-speech\temp\codes_0.npy...
# [OK] Audio decoded in 8.8s
# [3/3] Success! Audio saved to: C:\Users\PC\Desktop\fish-speech\temp\test_output_finetuned.wav
# Total time: 31.3s
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Next Steps
#
# Your finetuned model is at: `checkpoints/openaudio-s1-mini-{name}/`
#
# **Use in voice-service:**
# ```bash
# VOICE_S1_CHECKPOINT_PATH=checkpoints/openaudio-s1-mini-neymar
# ```
#
# **Enable LoRA hot-swap:**
# ```bash
# VOICE_LORA_ENABLED=true
# VOICE_LORA_PATH=results/neymar_finetune/checkpoints/step_xxx.ckpt
# ```
